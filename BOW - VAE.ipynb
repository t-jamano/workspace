# %%
from Models import *
from Utils import *
from FastModels import *
import warnings
from livelossplot import PlotLossesKeras
# warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
from gensim.models import KeyedVectors
import sentencepiece as spm

max_len = 20
enablePadding = False

sp = spm.SentencePieceProcessor()
sp.Load('/work/data/bpe/en.wiki.bpe.op50000.model')
bpe = KeyedVectors.load_word2vec_format("/work/data/bpe/en.wiki.bpe.op50000.d200.w2v.bin", binary=True)
bpe.index2word = [''] + bpe.index2word + ['<sos>']  # add empty string 
nb_words = len(bpe.index2word)
# word2index
bpe_dict = {bpe.index2word[i]: i for i in range(len(bpe.index2word))}
# construct embedding_matrix
embedding_matrix = np.concatenate([np.zeros((1, bpe.vector_size)), bpe.vectors, np.zeros((1, bpe.vector_size))]) # add zero vector for empty string (i.e. used for padding)

embedding_layer = Embedding(nb_words,
                    embedding_matrix.shape[-1],
                    weights=[embedding_matrix],
                    input_length=max_len,
                    trainable=True)

# %%
enablePadding = True
df_may, qrel_may = get_test_data("MayFlower", "/work/")
df_june, qrel_june = get_test_data("JuneFlower", "/work/")
df_july, qrel_july = get_test_data("JulyFlower", "/work/")

q_may = parse_texts_bpe(df_may.q.tolist(), sp, bpe_dict, max_len, enablePadding)
d_may = parse_texts_bpe(df_may.d.tolist(), sp, bpe_dict, max_len, enablePadding)

q_june = parse_texts_bpe(df_june.q.tolist(), sp, bpe_dict, max_len, enablePadding)
d_june = parse_texts_bpe(df_june.d.tolist(), sp, bpe_dict, max_len, enablePadding)

q_july = parse_texts_bpe(df_july.q.tolist(), sp, bpe_dict, max_len, enablePadding)
d_july = parse_texts_bpe(df_july.d.tolist(), sp, bpe_dict, max_len, enablePadding)

q_july_ = parse_texts_bpe(df_july.q.tolist(), sp, bpe_dict, max_len, enablePadding, "post")
d_july_ = parse_texts_bpe(df_july.d.tolist(), sp, bpe_dict, max_len, enablePadding, "post")

test_set = [[q_may, d_may, qrel_may, df_may, "MayFlower"], [q_june, d_june, qrel_june, df_june, "JuneFlower"], [q_july, d_july, qrel_july, df_july, "JulyFlower"]]
# Out:
# b'Skipping line 19898: expected 6 fields, saw 8\nSkipping line 20620: expected 6 fields, saw 8\nSkipping line 38039: expected 6 fields, saw 8\n'

# %%
def toBOW(x, nb_words):
    x_ = np.zeros((len(x), nb_words))
    for idx, i in enumerate(x):
        x_[idx][i] = 1
    return x_

# %%
q_bow_may = toBOW(q_may, nb_words)
d_bow_may = toBOW(d_may, nb_words)

q_bow_june = toBOW(q_june, nb_words)
d_bow_june = toBOW(d_june, nb_words)

q_bow_july = toBOW(q_july, nb_words)
d_bow_july = toBOW(d_july, nb_words)

# %%
from scipy.stats import wasserstein_distance
def eval_july(run, q_july, d_july, mode="cos"):
    q_ = run.predict(q_july)
    d_ = run.predict(d_july)
    
    if mode == "cos":
        cosine = CosineSim(q_.shape[-1])
        pred = cosine.model.predict([q_, d_])        
    else:
        pred = []
        for i in range(len(q_)):
            pred.append(wasserstein_distance(q_[i], d_[i]))
        pred = np.array(pred)

    print(auc(qrel_july, pred.flatten()))

# %%
class BOW_VAE(object):
    

    def __init__(self, input_size, max_len, embedding_matrix, dim, comp_topk=None, ctype=None, epsilon_std=1.0, optimizer=Adadelta(lr=2.), kl_weight=0, PoolMode="max"):
        self.input_size = input_size
        self.dim = dim
        self.embedding_matrix = embedding_matrix
        self.comp_topk = comp_topk
        self.ctype = ctype
        self.epsilon_std = epsilon_std
        self.max_len = max_len
        self.nb_words = input_size
        self.optimizer = optimizer
        self.kl_weight = kl_weight
        self.enableKL = True if kl_weight == 0 else False
        self.PoolMode = PoolMode
        self.build()

    def build(self):
        act = 'tanh'
        input_layer = Input(shape=(self.max_len,))
        emb_layer = Embedding(self.nb_words,
                            self.embedding_matrix.shape[-1],
                            weights=[self.embedding_matrix],
                            input_length=self.max_len,
                            trainable=True)

        hidden_layer1 = Dense(self.dim[0], kernel_initializer='glorot_normal', activation=act)
        
        Pooling = GlobalMaxPooling1D() if self.PoolMode == "max" else GlobalAveragePooling1D()

        h1 = Pooling(emb_layer(input_layer))
        
#         h1 = hidden_layer1(input_layer)

        self.z_mean = Dense(self.dim[1], kernel_initializer='glorot_normal')(h1)
        self.z_log_var = Dense(self.dim[1], kernel_initializer='glorot_normal')(h1)

        if self.comp_topk != None:
            self.z_mean_k = KCompetitive(self.comp_topk, self.ctype)(self.z_mean)
            encoded = Lambda(self.sampling, output_shape=(self.dim[1],))([self.z_mean_k, self.z_log_var])
        else:
            encoded = Lambda(self.sampling, output_shape=(self.dim[1],))([self.z_mean, self.z_log_var])


        decoder_h = Dense(self.dim[0], kernel_initializer='glorot_normal', activation=act)

        hidden2vocab = Dense(self.nb_words, activation='sigmoid', name="rec")
        h_decoded = decoder_h(encoded)
        h_decoded = hidden2vocab(h_decoded)
     
        self.model = Model(input_layer, [h_decoded, h_decoded])
        self.model.compile(optimizer=self.optimizer, loss=["binary_crossentropy", self.kl_loss])

        self.encoder = Model(outputs=self.z_mean, inputs=input_layer)


    def name(self):
        n = "vae_%s" % self.PoolMode if self.comp_topk == None else "kate_%s" % self.PoolMode
        n =  n + "_kl" if self.enableKL else n
        return n
    def sampling(self, args):
        z_mean, z_log_var = args
        epsilon = K.random_normal(shape=(K.shape(z_mean)[0], self.dim[1]), mean=0.,\
                                  stddev=self.epsilon_std)

        return z_mean + K.exp(z_log_var / 2) * epsilon


    def kl_loss(self, x, x_):
        if self.comp_topk != None:
            kl_loss = - 0.5 * K.sum(1 + self.z_log_var - K.square(self.z_mean_k) - K.exp(self.z_log_var), axis=-1)
        else:
            kl_loss = - 0.5 * K.sum(1 + self.z_log_var - K.square(self.z_mean) - K.exp(self.z_log_var), axis=-1)
        return self.kl_weight * kl_loss

# %%
K.clear_session()
run = BOW_VAE(nb_words, max_len, embedding_matrix, [200, 200], optimizer=Adam(), kl_weight=0.0001)

# %%
x_train = np.concatenate([q_july, d_july])
y_train = [np.concatenate([q_bow_july, d_bow_july]), np.concatenate([q_bow_july, d_bow_july])]
# y_train = [y_train, y_train]

# %%
for i in range(50):
    run.model.fit(x_train, y_train, verbose=2, batch_size=8)
#     eval_july(run.encoder, q_july, d_july, "wes")
    
#     kl_rate = 0.01
#     run.kl_weight = min(run.kl_weight + kl_rate, 1)
#     run.model.compile(optimizer=run.optimizer, loss=["binary_crossentropy", run.kl_loss])

    
    print(evaluate(run.encoder, test_set))
# Out:
# Epoch 1/1
#  - 3s - loss: 0.1236 - rec_loss_1: 0.0925 - rec_loss_2: 0.0310
# (0.5069370523131211, 0.8383219857882652, 0.565622984722809, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0211 - rec_loss_1: 0.0048 - rec_loss_2: 0.0163
# (0.508622162796155, 0.838533040906044, 0.5702372745669239, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0206 - rec_loss_1: 0.0038 - rec_loss_2: 0.0168
# (0.5078873864194655, 0.838329313674712, 0.5556939224799307, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0293 - rec_loss_1: 0.0041 - rec_loss_2: 0.0252
# (0.5068571407521472, 0.8384083860643323, 0.5724943850207921, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0314 - rec_loss_1: 0.0053 - rec_loss_2: 0.0261
# (0.5052393923513481, 0.8385065615124149, 0.5728168293713447, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0152 - rec_loss_1: 0.0020 - rec_loss_2: 0.0132
# (0.5070293705376486, 0.8386823433920142, 0.5595743734572706, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0149 - rec_loss_1: 0.0020 - rec_loss_2: 0.0130
# (0.5071541787472903, 0.8387767856751971, 0.5591185038582134, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0150 - rec_loss_1: 0.0029 - rec_loss_2: 0.0121
# (0.507446574430725, 0.8385049268108011, 0.5387711534612732, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0196 - rec_loss_1: 0.0046 - rec_loss_2: 0.0150
# (0.5058831693036243, 0.8381992829503595, 0.5600747181391625, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0203 - rec_loss_1: 0.0014 - rec_loss_2: 0.0188
# (0.5067204567892674, 0.8384983620908246, 0.5533589806311013, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0294 - rec_loss_1: 0.0055 - rec_loss_2: 0.0239
# (0.5073146138213196, 0.8392691534740793, 0.5527363294714136, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0269 - rec_loss_1: 0.0046 - rec_loss_2: 0.0223
# (0.5060577536299138, 0.8391146290589261, 0.5481776334808424, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0210 - rec_loss_1: 0.0035 - rec_loss_2: 0.0175
# (0.5060642012487945, 0.8390841353871268, 0.5657897662834397, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0284 - rec_loss_1: 0.0019 - rec_loss_2: 0.0265
# (0.5055369420563252, 0.8394231425675768, 0.558440258844982, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0227 - rec_loss_1: 0.0044 - rec_loss_2: 0.0183
# (0.5068967673693933, 0.8391360238855996, 0.5455202472814605, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0118 - rec_loss_1: 0.0018 - rec_loss_2: 0.0100
# (0.5068909775952967, 0.8386401530642914, 0.5395717049523004, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0103 - rec_loss_1: 0.0015 - rec_loss_2: 0.0089
# (0.5072989911303539, 0.8383744972977359, 0.543507749783184, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0220 - rec_loss_1: 0.0025 - rec_loss_2: 0.0195
# (0.5073942773492366, 0.8380703758849374, 0.5429184549356223, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0183 - rec_loss_1: 0.0020 - rec_loss_2: 0.0163
# (0.5075352395579209, 0.8383299499995778, 0.532099891036047, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0105 - rec_loss_1: 0.0015 - rec_loss_2: 0.0090
# (0.507250874006173, 0.837913900514093, 0.5312326269207677, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0258 - rec_loss_1: 0.0067 - rec_loss_2: 0.0191
# (0.5059983812577836, 0.8387532151603219, 0.5193466610331561, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0114 - rec_loss_1: 0.0021 - rec_loss_2: 0.0093
# (0.5054672388998147, 0.8387136609564088, 0.5300985123084792, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0312 - rec_loss_1: 0.0043 - rec_loss_2: 0.0269
# (0.5060027348840079, 0.8389602487807188, 0.5444083702105895, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0232 - rec_loss_1: 0.0023 - rec_loss_2: 0.0209
# (0.5058163737081259, 0.8386945200478568, 0.5416397963041206, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0251 - rec_loss_1: 0.0032 - rec_loss_2: 0.0219
# (0.505971326692678, 0.8387841255291727, 0.5382930463207988, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0100 - rec_loss_1: 0.0011 - rec_loss_2: 0.0089
# (0.506612339076726, 0.838812758490348, 0.5281638462051637, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0169 - rec_loss_1: 0.0027 - rec_loss_2: 0.0142
# (0.5075599829418793, 0.8383946220155823, 0.5117303030976895, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0268 - rec_loss_1: 0.0036 - rec_loss_2: 0.0232
# (0.5052091870072346, 0.8385682820479592, 0.5398496742200183, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0199 - rec_loss_1: 0.0020 - rec_loss_2: 0.0179
# (0.5048686195299122, 0.8387343729280609, 0.5348907024839333, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0295 - rec_loss_1: 0.0064 - rec_loss_2: 0.0231
# (0.5042439671357779, 0.8388442728410798, 0.5362694300518135, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0157 - rec_loss_1: 0.0013 - rec_loss_2: 0.0144
# (0.5050281311677112, 0.838685173609213, 0.5281749649758724, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0117 - rec_loss_1: 0.0017 - rec_loss_2: 0.0100
# (0.5053256316718501, 0.8389069536617743, 0.5296982365629656, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0142 - rec_loss_1: 0.0017 - rec_loss_2: 0.0125
# (0.505704829396035, 0.8385429955806586, 0.5383264026329249, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0245 - rec_loss_1: 0.0029 - rec_loss_2: 0.0217
# (0.5047449565694143, 0.8384594166497873, 0.5388712223976517, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0100 - rec_loss_1: 0.0011 - rec_loss_2: 0.0089
# (0.506872167187629, 0.8379330988884812, 0.534634970757633, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0189 - rec_loss_1: 0.0030 - rec_loss_2: 0.0160
# (0.5055465972540759, 0.8382348731908922, 0.5523582912673175, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0108 - rec_loss_1: 0.0018 - rec_loss_2: 0.0091
# (0.5055781189027403, 0.8378279608082025, 0.5488892348061998, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0109 - rec_loss_1: 9.3079e-04 - rec_loss_2: 0.0100
# (0.5066744151368882, 0.8381391694136193, 0.5377704640974894, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0090 - rec_loss_1: 0.0021 - rec_loss_2: 0.0069
# (0.5049966570584776, 0.8387205603739887, 0.5441304009428718, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0134 - rec_loss_1: 9.2330e-04 - rec_loss_2: 0.0125
# (0.5065442064334462, 0.8377493056372376, 0.5348795837132247, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0118 - rec_loss_1: 0.0018 - rec_loss_2: 0.0100
# (0.5051551906969287, 0.8380845115876291, 0.5504347439347106, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0252 - rec_loss_1: 0.0033 - rec_loss_2: 0.0219
# (0.5048978447404426, 0.837488194869797, 0.5558273477284351, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0106 - rec_loss_1: 7.9912e-04 - rec_loss_2: 0.0098
# (0.5068345092715221, 0.8377341128277692, 0.5481109208565901, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0182 - rec_loss_1: 0.0028 - rec_loss_2: 0.0154
# (0.506301719673088, 0.8372922204157782, 0.5412951144121506, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0097 - rec_loss_1: 0.0027 - rec_loss_2: 0.0070
# (0.505889960540659, 0.8374742449103244, 0.5393938046209611, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0110 - rec_loss_1: 8.1072e-04 - rec_loss_2: 0.0102
# (0.5062403008005711, 0.8369140657297386, 0.531721852831951, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0081 - rec_loss_1: 0.0015 - rec_loss_2: 0.0066
# (0.506051918923576, 0.8373471674735463, 0.5210367141808802, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0096 - rec_loss_1: 0.0011 - rec_loss_2: 0.0084
# (0.505935331348012, 0.8365865540206655, 0.5197802930907959, 0, 0, 0)
# Epoch 1/1
#  - 2s - loss: 0.0123 - rec_loss_1: 0.0014 - rec_loss_2: 0.0109
# (0.505461672577557, 0.8377967597545719, 0.5162334052347173, 0, 0, 0)
# Epoch 1/1
#  - 3s - loss: 0.0236 - rec_loss_1: 0.0034 - rec_loss_2: 0.0201
# (0.5054375433825312, 0.8373389234946316, 0.5326669483421913, 0, 0, 0)

# %%
w2v = Sequential([Embedding(nb_words,
                    embedding_matrix.shape[-1],
                    weights=[embedding_matrix],
                    input_length=max_len,
                    trainable=True), GlobalAveragePooling1D()])

# %%
w2v.predict(q_july).shape
# Out:
# (426, 20, 200)

# %%
df_sts_train = pd.read_csv("/work/data/train_data/sts-b/train.tsv", sep="\t",encoding='utf-8',quoting=3,  header=None, error_bad_lines=False, usecols=[5,6,4], names=["label","q","d"])
df_sts_dev = pd.read_csv("/work/data/train_data/sts-b/dev.tsv", sep="\t",encoding='utf-8',quoting=3,  header=None, error_bad_lines=False, usecols=[5,6,4], names=["label","q","d"])
df_sts_test = pd.read_csv("/work/data/train_data/sts-b/test.tsv", sep="\t",encoding='utf-8',quoting=3,  header=None, error_bad_lines=False, usecols=[5,6,4], names=["label","q","d"])

for df in [df_sts_train, df_sts_dev, df_sts_test]:
    df.q = df.q.astype(str).str.lower()
    df.d = df.d.astype(str).str.lower()

# %%
df_sts_test
# Out:
#       label                                                  q  \
# 0     2.500                        A girl is styling her hair.
# 1     3.600           A group of men play soccer on the beach.
# 2     5.000      One woman is measuring another woman's ankle.
# 3     4.200                    A man is cutting up a cucumber.
# 4     1.500                           A man is playing a harp.
# 5     1.800                         A woman is cutting onions.
# 6     3.500               A man is riding an electric bicycle.
# 7     2.200                        A man is playing the drums.
# 8     2.200                           A man is playing guitar.
# 9     1.714                         A man is playing a guitar.
# 10    1.714                         A man is playing a guitar.
# 11    5.000                         A man is cutting an onion.
# 12    0.600                                  A man is cycling.
# 13    4.400                      A man is slicing open a fish.
# 14    2.000                         A man is slicing a tomato.
# 15    1.800                         A man is playing a guitar.
# 16    4.400                    A baby panda goes down a slide.
# 17    3.600             A man is singing and playing a guitar.
# 18    3.600                             A man attacks a woman.
# 19    1.200                            A man is driving a car.
# 20    2.400                           A woman is cutting tofu.
# 21    0.200                     The woman is styling her hair.
# 22    4.200                  Two zebras play in an open field.
# 23    4.400                         A man is cutting a potato.
# 24    2.250                         A man is slicing an onion.
# 25    2.000                                 A  man is dancing.
# 26    0.750                      A man is riding a motorcycle.
# 27    2.200                        A woman is slicing garlics.
# 28    0.800                                 A man is speaking.
# 29    2.200      A little boy is singing and playing a guitar.
# ...     ...                                                ...
# 1349  2.000          US drone strike kills eight in Waziristan
# 1350  5.000       Russian opposition leader under house arrest
# 1351  5.000  Senate confirms Janet Yellen as chair of US Fe...
# 1352  5.000   Israel confirms strike on Syria targeted weapons
# 1353  5.000  Jurors find Jodi Arias eligible for death penalty
# 1354  4.000              Twitter reports blocking in Venezuela
# 1355  3.000        Goa building collapse death toll touches 15
# 1356  3.000      Pak religious body endorses underage marriage
# 1357  5.000    Mt Gox reveals 200,000 'forgotten' bitcoin haul
# 1358  4.000         More than 100 injured in Texas plant blast
# 1359  2.000  Redford touts Alberta economy ahead of vote on...
# 1360  1.000                 Obama holds out over Syria strikes
# 1361  4.000  South Korean soldier reportedly flees after ki...
# 1362  0.000  Tycoon claims win in Ukraine and promises to s...
# 1363  2.000         Syria agrees to surrender chemical weapons
# 1364  5.000  AbbVie Sours on $55B Shire Deal After Tax Changes
# 1365  3.000  Militant attack from Afghanistan kills four in...
# 1366  2.000                   13 killed in Afgan terror attack
# 1367  2.000                         Rev's Early Reads: March 2
# 1368  0.000                      Pope canonizes 2 Palestinians
# 1369  0.000    Funeral of Ian Paisley to take place in Belfast
# 1370  1.000                     Waba emerges new NLC president
# 1371  1.000      5 US airstrikes target Islamic State fighters
# 1372  1.000  US Senate votes to advance Iran nuclear review...
# 1373  2.000  Editors from around the world urge Turkey to p...
# 1374  0.000  Philippines, Canada pledge to further boost re...
# 1375  1.000  Israel bars Palestinians from Jerusalem's Old ...
# 1376  1.000         How much do you know about Secret Service?
# 1377  0.000  Obama Struggles to Soothe Saudi Fears As Iran ...
# 1378  0.000          South Korea declares end to MERS outbreak
#
#                                                       d
# 0                          A girl is brushing her hair.
# 1      A group of boys are playing soccer on the beach.
# 2               A woman measures another woman's ankle.
# 3                          A man is slicing a cucumber.
# 4                          A man is playing a keyboard.
# 5                              A woman is cutting tofu.
# 6                            A man is riding a bicycle.
# 7                          A man is playing the guitar.
# 8                         A lady is playing the guitar.
# 9                           A man is playing a trumpet.
# 10                          A man is playing a trumpet.
# 11                                 A man cuts an onion.
# 12                                    A man is talking.
# 13                          A man is cutting up a fish.
# 14                              A man is slicing a bun.
# 15                         A man is playing a keyboard.
# 16                         A panda slides down a slide.
# 17                           A man is playing a guitar.
# 18                                 A man slaps a woman.
# 19                             A man is riding a horse.
# 20                         A woman is cutting an onion.
# 21                          The woman is slicing herbs.
# 22                   Two zebras are playing in a field.
# 23                        A man is slicing some potato.
# 24                        A woman is slicing a pumpkin.
# 25                          A man and woman is dancing.
# 26                           A woman is riding a horse.
# 27                         A woman is slicing an onion.
# 28                                    A man is cooking.
# 29             A man is singing and playing the guitar.
# ...                                                 ...
# 1349               US drone strike kills 11 in Pakistan
# 1350  Russian Opposition Leader Placed Under House A...
# 1351  Senate confirms Janet Yellen as next Federal R...
# 1352  Israel officials: Strike on Syria targeted wea...
# 1353   Jodi Arias eligible for death penalty, jury says
# 1354           Twitter says images blocked in Venezuela
# 1355         Indian building collapse deaths rise to 14
# 1356                     CII endorses underage marriage
# 1357          Mt Gox finds 200,000 'forgotten' bitcoins
# 1358  Hundreds believed injured in Texas fertiliser ...
# 1359  Redford addresses PC convention ahead of leade...
# 1360                  UK urges countries over Syria aid
# 1361      South Korean Soldier Kills Comrades And Flees
# 1362  Polling stations open at Ukrainian presidentia...
# 1363  UK's Cameron: Syria, Russia must show chemical...
# 1364  AbbVie cools on $55bn Shire deal after US tax ...
# 1365  Militant attack from Afghanistan kills FC sold...
# 1366           6 killed in Afghan capital mosque attack
# 1367                Rev.'s Early Reads: Sept. 3rd, 2015
# 1368                Sweden recognizes Palestinian state
# 1369  Funeral of MH17 victim Liam Sweeney takes plac...
# 1370                     Waiting for the next president
# 1371      Kurds see Turkey impeding Islamic State fight
# 1372             US scientists praise Iran nuclear deal
# 1373     Media freedom at stake as Turkey fights rebels
# 1374            Philippines saves 100 after ferry sinks
# 1375  Two-state solution between Palestinians, Israe...
# 1376  Lawmakers from both sides express outrage at S...
# 1377  Myanmar Struggles to Finalize Voter Lists for ...
# 1378  North Korea Delegation Meets With South Korean...
#
# [1379 rows x 3 columns]

# %%
# No labels on test set for Quora
df_quora_train = pd.read_csv("/work/data/train_data/quora/train.tsv", sep="\t",encoding='utf-8',quoting=3,  header=None, error_bad_lines=False, usecols=[3,4,5], names=["q","d","label"])
df_quora_dev = pd.read_csv("/work/data/train_data/quora/dev.tsv", sep="\t",encoding='utf-8',quoting=3,  header=None, error_bad_lines=False, usecols=[3,4,5], names=["q","d","label"])

for df in [df_quora_train, df_quora_val]:
    df.q = df.q.astype(str).str.lower()
    df.d = df.d.astype(str).str.lower()

# %%
# No labels on test set for Quora
df_para_train = pd.read_csv("/work/data/train_data/para/ParaphraseIdeal.txt", sep="\t",encoding='utf-8',quoting=3,  header=None, error_bad_lines=False, usecols=[0,1,2], names=["q","d","label"])

for df in [df_para_train]:
    df.q = df.q.astype(str).str.lower()
    df.d = df.d.astype(str).str.lower()

# %%
from scipy import stats
from sklearn.metrics import accuracy_score

def eval(run, df, mode="auc"):
    
    enablePadding = True
    q = parse_texts_bpe(df.q.tolist(), sp, bpe_dict, max_len, enablePadding)
    d = parse_texts_bpe(df.d.tolist(), sp, bpe_dict, max_len, enablePadding)
    
    q_ = run.predict(q)
    d_ = run.predict(d)
    cosine = CosineSim(q_.shape[-1])

    pred = cosine.model.predict([q_, d_]).flatten()
    
    if mode == "auc":
        print(auc(df.label.values, pred))
    else:
        print(scipy.stats.pearsonr(pred, df.label.values)[0])
#     print(scipy.stats.spearmanr(pred, label)[0])

# %%
eval(w2v, df_para_train)
# Out:
# 0.9388301628808409

# %%
eval(w2v, df_quora_dev)
# Out:
# 0.704084157177363

# %%
eval(w2v, df_sts_dev, "pcc")
eval(w2v, df_sts_test, "pcc")
# Minh's result = 0.75, max = 0.65
# Out:
# 0.5432863604684736
# 0.43498635136840813

# %%
length = []
for i in [q_sts2015_df, d_sts2015_df]:
    for j in i:
        l = len(j)
        length.append(l)
print(np.max(length), np.mean(length))
# Out:
# 659 16.516648853079012

# %%
run = SeqVAE(nb_words, max_len, embedding_matrix, [200,200], optimizer=Adam(), kl_weight=1)
