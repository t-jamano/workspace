# %% [markdown]
# # Generating Sentences from a Continuous Space
# ### Samuel R. Bowman, Luke Vilnis, Oriol Vinyals, Andrew M. Dai, Rafal Jozefowicz, Samy Bengio

# %%
from Models import *
from Utils import *
from FastModels import *
import warnings
from livelossplot import PlotLossesKeras
# warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
from gensim.models import KeyedVectors
import sentencepiece as spm

max_len = 15
enablePadding = True

sp = spm.SentencePieceProcessor()
sp.Load('/work/data/bpe/en.wiki.bpe.op50000.model')
bpe = KeyedVectors.load_word2vec_format("/work/data/bpe/en.wiki.bpe.op50000.d200.w2v.bin", binary=True)
bpe.index2word = [''] + bpe.index2word + ['<sos>'] + ['<eos>']  # add empty string 
nb_words = len(bpe.index2word)
# word2index
bpe_dict = {bpe.index2word[i]: i for i in range(len(bpe.index2word))}
# construct embedding_matrix
embedding_matrix = np.concatenate([np.zeros((1, bpe.vector_size)), bpe.vectors, np.zeros((2, bpe.vector_size))]) # add zero vector for empty string (i.e. used for padding)

embedding_layer = Embedding(nb_words,
                    embedding_matrix.shape[-1],
                    weights=[embedding_matrix],
                    input_length=max_len,
                    trainable=True)

# %%
from keras.layers import multiply
inp1 = Input((15,))
inp2 = Input((15,3,))

a = embedding_layer(inp1)
b = embedding_layer(inp2)

x = multiply([a, b])
x = Activation("softmax")(x)
run = Model([inp1, inp2], x)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     670           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 671           input_tensors_as_shapes, status)
#     672   except errors.InvalidArgumentError as err:
#
# /usr/local/anaconda3/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      88             try:
# ---> 89                 next(self.gen)
#      90             except StopIteration:
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Dimensions must be equal, but are 15 and 3 for 'multiply_1/mul' (op: 'Mul') with input shapes: [?,15,200], [?,15,3,200].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-c347dd4c5ffd> in <module>()
#       6 b = embedding_layer(inp2)
#       7
# ----> 8 x = multiply([a, b])
#       9 x = Activation("softmax")(x)
#      10 run = Model([inp1, inp2], x)
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/layers/merge.py in multiply(inputs, **kwargs)
#     572         A tensor, the element-wise product of the inputs.
#     573     """
# --> 574     return Multiply(**kwargs)(inputs)
#     575
#     576
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     601
#     602             # Actually call the layer, collecting output(s), mask(s), and shape(s).
# --> 603             output = self.call(inputs, **kwargs)
#     604             output_mask = self.compute_mask(inputs, previous_mask)
#     605
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/layers/merge.py in call(self, inputs)
#     144                 return y
#     145         else:
# --> 146             return self._merge_function(inputs)
#     147
#     148     def compute_output_shape(self, input_shape):
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/layers/merge.py in _merge_function(self, inputs)
#     257         output = inputs[0]
#     258         for i in range(1, len(inputs)):
# --> 259             output *= inputs[i]
#     260         return output
#     261
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#     819       if not isinstance(y, sparse_tensor.SparseTensor):
#     820         y = ops.convert_to_tensor(y, dtype=x.dtype.base_dtype, name="y")
# --> 821       return func(x, y, name=name)
#     822
#     823   def binary_op_wrapper_sparse(sp_x, y):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1042   is_tensor_y = isinstance(y, ops.Tensor)
#    1043   if is_tensor_y:
# -> 1044     return gen_math_ops._mul(x, y, name=name)
#    1045   else:
#    1046     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _mul(x, y, name)
#    1432     A `Tensor`. Has the same type as `x`.
#    1433   """
# -> 1434   result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#    1435   return result
#    1436
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     766         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     767                          input_types=input_types, attrs=attr_protos,
# --> 768                          op_def=op_def)
#     769         if output_structure:
#     770           outputs = op.outputs
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2336                     original_op=self._default_original_op, op_def=op_def)
#    2337     if compute_shapes:
# -> 2338       set_shapes_for_outputs(ret)
#    2339     self._add_op(ret)
#    2340     self._record_op_seen_by_control_dependencies(ret)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shapes_for_outputs(op)
#    1717       shape_func = _call_cpp_shape_fn_and_require_op
#    1718
# -> 1719   shapes = shape_func(op)
#    1720   if shapes is None:
#    1721     raise RuntimeError(
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in call_with_requiring(op)
#    1667
#    1668   def call_with_requiring(op):
# -> 1669     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1670
#    1671   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in call_cpp_shape_fn(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     608     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     609                                   input_tensors_as_shapes_needed,
# --> 610                                   debug_python_shape_fn, require_shape_fn)
#     611     if not isinstance(res, dict):
#     612       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, debug_python_shape_fn, require_shape_fn)
#     674       missing_shape_fn = True
#     675     else:
# --> 676       raise ValueError(err.message)
#     677
#     678   if missing_shape_fn:
#
# ValueError: Dimensions must be equal, but are 15 and 3 for 'multiply_1/mul' (op: 'Mul') with input shapes: [?,15,200], [?,15,3,200].

# %%
x1 = np.random.randint(100, size=(1,15))
x2 = np.random.randint(100, size=(1,15,3))

run.predict([x1, x2]).shape
# Out:
# (1, 15, 3)

# %%
x1
# Out:
# array([[37, 49, 40, 95, 11, 56, 63, 14, 32, 65, 65, 36, 25, 76, 72]])

# %%
neg_samples = []
for i in x1:
    for j in i:
        neg = np.random.randint(100, size=100)
        while j in neg:
            neg = np.random.randint(100, size=100)
        neg_samples.append(neg)
neg_samples = np.array(neg_samples)

# %%
neg_samples.shape
# Out:
# (1, 100)

# %%
model = Sequential([embedding_layer, Bidirectional(GRU(10, return_sequences=True)), Dense(100, activation="softmax")])

# %%
model.predict(q_july).shape
# Out:
# (426, 15, 100)

# %%
[{"loss_weights": {"yfake": 1e-2, "yreal": 1e-2, "xpred": 1}}] * 2
# Out:
# [{'loss_weights': {'xpred': 1, 'yfake': 0.01, 'yreal': 0.01}},
#  {'loss_weights': {'xpred': 1, 'yfake': 0.01, 'yreal': 0.01}}]

# %%
inputs = Input((max_len,200,))
dense = Dense(nb_words, use_bias=False, weights=[embedding_matrix.T], activation="linear", trainable=True)
h = Dense(1, activation="sigmoid")
model = Model(inputs, h(dense(inputs)))
model.compile(Adam(1), "binary_crossentropy")
# model = Sequential([embedding_layer, LSTM(200, return_sequences=True)])

# %%
x = np.random.randint(nb_words, size=(nb_words,max_len,200))
y = np.random.randint(2, size=(nb_words,max_len,1))
model.fit(x, y, verbose=2, epochs=1)
# Out:
# Epoch 1/1
#  - 17s - loss: 7.9639

# %%
def train(self, path, train_data, batch_size):

    x_train, y_train, valid, fake = self.get_training_data(path, train_data)

    max_val_loss = float("inf") 

    for i in range(100):
        latent_fake = run.gs_encoder.predict(x_train[0])
        latent_real = np.random.normal(size=(len(x_train[0]), self.latent_dim))

        d_loss_real = run.discriminator.fit(latent_real, valid, batch_size=batch_size, verbose=1)
        d_loss_fake = run.discriminator.fit(latent_fake, fake, batch_size=batch_size, verbose=1)


        d_loss = 0.5 * np.add(d_loss_real.history['loss'], d_loss_fake.history['loss'])
        d_acc = 0.5 * np.add(d_loss_real.history['acc'], d_loss_fake.history['acc'])
        print(d_loss, d_acc)

        hist = self.model.fit(x_train, y_train,
                                        shuffle=True,
                                        verbose=1,
                                        batch_size=batch_size,
                                        validation_split=0.2,
                                        callbacks=[EarlyStopping()]
                                        )
        if max_val_loss < hist.history["val_loss"][0]:
            break
        else:
            max_val_loss = hist.history["val_loss"][0]
    may_ndcg, june_ndcg, july_auc, quora_auc, para_auc, sts_pcc = evaluate(self.encoder, test_set)
    print(may_ndcg, june_ndcg, july_auc, quora_auc, para_auc, sts_pcc)

# %%
model.get_weights()[0] == embedding_matrix.T
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
x = model.predict(np.random.randint(nb_words, size=(20,max_len,200)))

# %%
x.shape
# Out:
# (20, 15, 50512)

# %%
embedding_matrix.shape
# Out:
# (50512, 200)

# %%
x = np.random.randint(200, size=(200))

# %%
x
# Out:
# array([173,  18, 168, 133, 139, 168, 179, 189,   4, 123,  79, 121,  83,
#         45,  87,  97,  40, 153, 157,  65, 198, 199,  68,   0, 153,  48,
#        193,  85,  69,  62, 130,  99,   2, 142, 122, 169,  16, 126,  24,
#         34,  33, 101, 135, 142, 149, 138, 149,  49,  72,  46,  37, 179,
#         10, 124,  16, 161, 138, 106,  78,  58,  52,  87,   3, 132, 110,
#         66, 148,  60,  54,   4, 154,  10,  29,  77, 145, 154, 156,  54,
#        104,  65, 105, 136,  70,  73, 197, 184, 118, 142, 117,   5, 134,
#         21,  39,  37, 162, 117, 176, 141, 103, 181, 105,  28, 155,  98,
#        196,  43, 149,  54,  62, 159,  95,  46,  76,  31, 118,   0,  70,
#        128,  18,  71, 189, 182, 182, 187,  26, 103,  38, 100,  26,  59,
#         98,   0, 152, 194, 155, 127, 109,  84, 153,  98,  35, 130, 123,
#         66, 102, 122,  87,   4, 117, 164, 172, 106, 160,  61,  42,  55,
#        147, 105,  16, 156, 136, 190,  42,  42,  46,  94,  49,  24,  32,
#          9,  14, 153, 198, 147, 141,  82, 135, 111,  33,   6,  96,  17,
#        180, 137,  60,  23, 172,  50,  54, 177,  27,  88, 103, 185, 139,
#         32,  34, 158,  30,  15])

# %%
enablePadding = True
df_may, qrel_may = get_test_data("MayFlower", "/work/")
df_june, qrel_june = get_test_data("JuneFlower", "/work/")
df_july, qrel_july = get_test_data("JulyFlower", "/work/")

q_may = parse_texts_bpe(df_may.q.tolist(), sp, bpe_dict, max_len, enablePadding)
d_may = parse_texts_bpe(df_may.d.tolist(), sp, bpe_dict, max_len, enablePadding)

q_june = parse_texts_bpe(df_june.q.tolist(), sp, bpe_dict, max_len, enablePadding)
d_june = parse_texts_bpe(df_june.d.tolist(), sp, bpe_dict, max_len, enablePadding)

q_july = parse_texts_bpe(df_july.q.tolist(), sp, bpe_dict, max_len, enablePadding)
d_july = parse_texts_bpe(df_july.d.tolist(), sp, bpe_dict, max_len, enablePadding)

q_july_ = parse_texts_bpe(df_july.q.tolist(), sp, bpe_dict, max_len, enablePadding, "post")
d_july_ = parse_texts_bpe(df_july.d.tolist(), sp, bpe_dict, max_len, enablePadding, "post")

test_set = [[q_may, d_may, qrel_may, df_may, "MayFlower"], [q_june, d_june, qrel_june, df_june, "JuneFlower"], [q_july, d_july, qrel_july, df_july, "JulyFlower"]]
# Out:
# b'Skipping line 19898: expected 6 fields, saw 8\nSkipping line 20620: expected 6 fields, saw 8\nSkipping line 38039: expected 6 fields, saw 8\n'

# %%
path = "/work/"
test_set = []
for i in ["MayFlower", "JuneFlower", "JulyFlower", "sts", "quora", "para"]:
    df, qrel = get_test_data(i, path)
    q_ = parse_texts_bpe(df.q.tolist(), sp, bpe_dict, max_len, enablePadding)
    d_ = parse_texts_bpe(df.d.tolist(), sp, bpe_dict, max_len, enablePadding)
    test_set.append([q_, d_, qrel, df, i])
# Out:
# b'Skipping line 19898: expected 6 fields, saw 8\nSkipping line 20620: expected 6 fields, saw 8\nSkipping line 38039: expected 6 fields, saw 8\n'

# %%
w2v = Sequential([embedding_layer, GlobalAveragePooling1D()])

# %%
q_ = w2v.predict(q_july, batch_size=1024)
d_ = w2v.predict(d_july, batch_size=1024)
cosine = CosineSim(q_.shape[-1])

pred = cosine.model.predict([q_, d_]).flatten()

# %%
pred
# Out:
# array([ 0.7406662 ,  0.85557044,  0.78561455,  0.9508481 ,  0.21879916,
#         0.7453836 ,  0.80263525,  0.8800487 ,  0.8917499 ,  0.5874681 ,
#         0.9321384 ,  0.88207304,  0.7556136 ,  0.8058573 ,  0.88766676,
#         0.8182602 ,  0.8318534 ,  0.8535499 ,  0.80444926,  0.81576264,
#         0.62067056,  0.8917444 ,  0.93127614,  0.5516985 ,  0.857374  ,
#         0.5215678 ,  0.9288186 ,  0.7079005 ,  0.88658553,  0.86006874,
#         0.9413204 ,  0.7012834 ,  0.8655325 ,  0.755405  ,  0.8400105 ,
#         0.88489044,  0.7711162 ,  0.9874416 ,  0.88372344,  0.9514174 ,
#         0.941886  ,  0.7015183 ,  0.9477373 ,  0.7320513 ,  0.93454653,
#         0.9042805 ,  0.8875321 ,  0.74232346,  0.9438862 ,  0.9163721 ,
#         0.87749827,  0.9541501 ,  0.4047952 ,  0.85031843,  0.85417974,
#         0.85163665,  0.50695676,  0.6544419 ,  0.8293873 ,  0.9354186 ,
#         0.8519439 ,  0.7906865 ,  0.8190459 ,  0.9502037 ,  0.85178924,
#         0.9198481 ], dtype=float32)

# %%
len(qrel_july[qrel_july == 1]), len(qrel_july[qrel_july == 0])
# Out:
# (193, 233)

# %%
evaluate(w2v, test_set)
# Out:
# (0.5140063870919466,
#  0.8463482465188383,
#  0.518468278147168,
#  0.7317146600481685,
#  0.9301704561504908,
#  0.4440271653122348)

# %%
def eval_july(run):
    q_ = run.predict(q_july)
    d_ = run.predict(d_july)
    cosine = CosineSim(q_.shape[-1])

    pred = cosine.model.predict([q_, d_])
    print(auc(qrel_july, pred.flatten()))

# %%
df = pd.read_csv("/work/data/train_data/30M_QD_lower2.txt", nrows=10000, names=["label", "q", "d"], sep="\t", header=None, error_bad_lines=False)
# df = df[df.label == 1]

# df = pd.read_csv("/work/data/train_data/QueryLog", nrows=100000, names=["q"], sep="\t", header=None, error_bad_lines=False)

# %%
enablePadding = True
q_df = parse_texts_bpe(df.q.tolist(), sp, bpe_dict, max_len, enablePadding, "post")
d_df = parse_texts_bpe(df.d.tolist(), sp, bpe_dict, max_len, enablePadding, "post")

# %%
# np.save("/work/data/train_data/1M_QD.q.npy", q_df)
# np.save("/work/data/train_data/1M_QD.d.npy", d_df)
# np.save("/work/data/train_data/1M_QD.label.npy", df.label.values)

# %%
q = np.load("/work/data/train_data/100K_QD_ml15.q.npy")[:10000]
qdi = np.load("/work/data/train_data/100K_QD_ml15.q.di.npy")[:10000]
qdo = np.load("/work/data/train_data/100K_QD_ml15.q.do.npy")[:10000]

d = np.load("/work/data/train_data/100K_QD_ml15.d.npy")[:10000]
ddi = np.load("/work/data/train_data/100K_QD_ml15.d.di.npy")[:10000]
ddo = np.load("/work/data/train_data/100K_QD_ml15.d.do.npy")[:10000]

# %%
def get_tokens(df):
    tokens = set([])
    for i in df:
        for j in i:
            tokens.add(j)
    return tokens

july_tokens = get_tokens(np.concatenate([q_july, d_july]))
june_tokens = get_tokens(np.concatenate([q_june, d_june]))
may_tokens = get_tokens(np.concatenate([q_may, d_may]))

train_tokens = get_tokens(q_df)
for i in [july_tokens, june_tokens, may_tokens]:
    print("Train %d, Test %d, Overlap %d" % (len(train_tokens), len(i), len(train_tokens.intersection(i))))
# Out:
# Train 29279, Test 1523, Overlap 1464
# Train 29279, Test 10049, Overlap 9274
# Train 29279, Test 10561, Overlap 9854

# %%
K.clear_session()
kl_rate = 0.01
keep_rate_word_dropout = 0.75
run = Seq2Seq(nb_words, max_len, embedding_matrix, [200,100], Adam(), kl_rate, keep_rate_word_dropout, mode=1, enableKL=True, enableS2S=False)

# %%
for i in range(30):
    kl_weight = 1
    x_train = [q, qdi] + [np.array([kl_weight] * len(q))]
    y_train = [np.expand_dims(qdo, axis=-1), np.ones(len(qdo))]
    hist = run.model.fit(x_train, y_train, verbose=2,batch_size=256)
    print(evaluate(run.encoder, test_set))
# Out:
# Epoch 1/1
#  - 14s - loss: 1.3279 - rec_loss: 1.3278 - kl_loss: 1.1052e-04
# (0.49573213269410454, 0.8271802074919363, 0.5322777913673864, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3310 - rec_loss: 1.3309 - kl_loss: 1.4369e-04
# (0.49700126026727803, 0.8284703563578426, 0.5154217349729814, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3319 - rec_loss: 1.3317 - kl_loss: 1.5625e-04
# (0.4986811292663033, 0.8284686959008363, 0.5466432431230404, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3318 - rec_loss: 1.3316 - kl_loss: 1.5749e-04
# (0.4971709287759919, 0.8299626597306875, 0.5374146634348106, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3317 - rec_loss: 1.3315 - kl_loss: 1.4919e-04
# (0.4973130620148586, 0.8284320371335961, 0.5194912050523695, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3300 - rec_loss: 1.3298 - kl_loss: 1.4954e-04
# (0.4972599356660459, 0.8286235417083805, 0.5486446218506082, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3291 - rec_loss: 1.3289 - kl_loss: 1.3506e-04
# (0.49860879214391884, 0.8302246223549468, 0.5365696368609486, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3290 - rec_loss: 1.3289 - kl_loss: 1.3447e-04
# (0.49708810820757793, 0.8289209246950308, 0.5240943761257755, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3282 - rec_loss: 1.3281 - kl_loss: 1.4716e-04
# (0.49814543717192883, 0.8287430460919655, 0.5325891169472303, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3283 - rec_loss: 1.3281 - kl_loss: 1.5657e-04
# (0.49793731014933923, 0.8293024864510447, 0.5172229758277924, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3295 - rec_loss: 1.3294 - kl_loss: 1.4271e-04
# (0.4973041359500977, 0.829444783861826, 0.5206253196646579, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3286 - rec_loss: 1.3285 - kl_loss: 1.4740e-04
# (0.4966914469135078, 0.8277901397626093, 0.5330338677755788, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3279 - rec_loss: 1.3278 - kl_loss: 1.4872e-04
# (0.4967856078427329, 0.8298034146902704, 0.532411216615891, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3280 - rec_loss: 1.3279 - kl_loss: 1.3394e-04
# (0.49708073873429065, 0.8288844245267895, 0.5414396584313639, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3280 - rec_loss: 1.3279 - kl_loss: 1.5247e-04
# (0.4943410545876417, 0.8254709538541304, 0.5469768062443017, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3273 - rec_loss: 1.3271 - kl_loss: 1.7944e-04
# (0.4969395188235516, 0.8270663102688219, 0.5414841335141987, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3264 - rec_loss: 1.3262 - kl_loss: 1.5468e-04
# (0.497518048139247, 0.8286156044977209, 0.5099957748671307, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3266 - rec_loss: 1.3265 - kl_loss: 1.4804e-04
# (0.49637867616228176, 0.827559595600417, 0.5447085770197246, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3264 - rec_loss: 1.3263 - kl_loss: 1.5666e-04
# (0.49507584619550377, 0.8273781539159177, 0.5347683960061376, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3252 - rec_loss: 1.3251 - kl_loss: 1.5275e-04
# (0.49725460062239973, 0.8279556655583815, 0.5062821054504214, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3266 - rec_loss: 1.3265 - kl_loss: 1.3854e-04
# (0.49701090472936443, 0.8277734693323114, 0.540972670061598, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3255 - rec_loss: 1.3254 - kl_loss: 1.4563e-04
# (0.4995360296298393, 0.8271115054243583, 0.5293869109831217, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3236 - rec_loss: 1.3234 - kl_loss: 1.4401e-04
# (0.49832327750208844, 0.8281106930007679, 0.5437523627387756, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3230 - rec_loss: 1.3228 - kl_loss: 1.4136e-04
# (0.4964375421972639, 0.8277742973790441, 0.5347239209233028, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3202 - rec_loss: 1.3201 - kl_loss: 1.3925e-04
# (0.49801622210914703, 0.8290193112892456, 0.49905490448975953, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3221 - rec_loss: 1.3219 - kl_loss: 1.4749e-04
# (0.4957777043968141, 0.8278575471081224, 0.5174898263248016, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3215 - rec_loss: 1.3213 - kl_loss: 1.4530e-04
# (0.49669232285638504, 0.8265590293928281, 0.5434410371589318, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3216 - rec_loss: 1.3214 - kl_loss: 1.5254e-04
# (0.4965460799364312, 0.8287727176190719, 0.5260512797705086, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3242 - rec_loss: 1.3241 - kl_loss: 1.5058e-04
# (0.49718614928808336, 0.8283613402159288, 0.5413062331828593, 0, 0, 0)
# Epoch 1/1
#  - 14s - loss: 1.3234 - rec_loss: 1.3233 - kl_loss: 1.3079e-04
# (0.4975430526304311, 0.827938204395651, 0.5370366252307145, 0, 0, 0)

# %%
generate_output(run.model, bpe, [q_july, dec_input],  idx=0)
# Out:
# BLEU: 0.6552
#               should you get rental car insurance	what is of of of of
#                police radar how it works	what is of
#                 native tribes of arizona	what of of
#              how long spaghetti sauce in refriger ator	what of of
#                 clayton county in ga	what of of
#          when is gay pride parade in nyc  2 0 <unk>	what is of of of of of
#              easy chicken breast recipes cro ck pot	what of
#             what to do in g ta  <unk>	what is is is of of of of
#                 dancing with  stars	what of of
#               leonardo dic ap rio wife name	what of
#                  is doge dead	what of of
#                 super class in java	what of of
#                   hungry hearts
#              phar rell williams desp icable me soundtrack
#                best resources for salary range	what is of of
#                  definition grie vance	what of
#             author of dr jek yll and mr hyde	what is of of
#               is coal  leading energy source	what is of of
#                 rod stewart best songs	what of of
#                  im rl definition	what of of
#                 calc u ium carbonate	what of
#              beverly hills md dark circle corre ctor	what of
#                secretary of state of michigan	what is of of
#                  kir stin powers
#                  h pyl ori	what of
#                is my transmission going out	what is of of of of of of of of of of of of of of of of of of
#               <unk> 2 1 silver dollar value	what is of of
#            average monthly temperatures in dest in beach , florida	what is of of of of
#               american horror story season  <unk>	what of of of of of
#                 annual temperature range ia	what of of
#                 oven fried green tomatoes
#                  car salesman kidnapped	what of
#               ank yl osing sp ondyl itis	what of
#                 bru ised heel cure	what
#                   red symbolism	what of
#               cleaning st ains from vinyl siding	what of of
#                  pilot training requirements	what of
#                 amit abh bachchan news
#           what kind of dog was in turner and ho och	what is of of
#           difference between whe y protein and whe y protein isolate	what is of of of of
#               can guinea pigs eat car rots	what is of of
#              difference between ec g and ek g	what of of of
#              country that links north and south america	what is of of of
#                and so it goes trailer	what of of of
#                great smoky mountains national park	what of of of
#                 <unk> bmw z 3	what of of
#                bridge with locks in paris	what of of
#             average cost of car  2 0 <unk>	what is of of of of
#              who is  director of train wreck	what is of of of
#                   adolf hitler
#                   employment agency	what of
#                 birmingham england botanical gardens	what of
#                 bey once blow lyrics
#              which is a good conductor of electricity	what is of of of
#                 drugs used for depression	what of of
#                 cp ap machines reviews
#                  american eg ale	what of
#                mid s omer murders cast	what of of
#                  <unk> area code	what is of of
#               why doesn ' t chrome open	what of of of
#                 securities in stock market	what of of
#            how to manage who sees your photos on facebook	what is of of of of
#           google . com / andro id / dev ice manager	what is of of of
#              employer contribution to h sa tax able	what is of of of
#               bank of america short sale package	what is of of
#                average cost of ky bella	what of of of
#                  tulsa tv stations	what
#                actors from  o men	what is of of
#             how much do auto dealership drivers make ?	what is is of of
#               denny sanford premier center seating chart	what of
#               1 st class letter to canada	what is of of
#                kendall jenn er last name	what of
#                home pages for internet explorer	what of of
#               acute gall blad der attack symptoms	what of
#                  ben bridge jewelry	what of
#              ur anus how far from  sun	what is of of
#              1 00 grams equals how many kilograms	what of of of of
#                   bio examples
#            pilot who landed  plane in  hudson river	what is of of of
#                 which muscle open jaw	what is of
#              signs of a heart attack for men	what is of of
#                can i gift a car	what is of of of
#                 apa inte xt citations
#                first national bank credit card	what is of of
#                  christopher reeve movies
#               david bald acci list of books	what of of
#                 cold well banker realty
#                 eggs in  microwave	what of of
#                 ad t customer service	what of of
#                   joey lawrence
#              how to get rid of pimp les	what is of of of
#                  family feud halloween	what of
#                secretary of state of maryland	what is of of
#                lies my history teacher told	what of of of
#                  kinds of arthritis	what of
#                 great white sharks habitat	what of of of
#                  donna mills actress	what of
#                types of cer ner certifications	what of of
#              how to screen shot on a mac	what is of of of
#                 dish network remote control	what of
#                 madness of king george	what of of
#              what level does tir to uga evolve	what is of of of
#                  lazy boy furniture
#                and so it goes trailer	what is of
#                great smoky mountains national park	what is of
#                 zoe z ald ana	of
#             what does f ** * you mean ?	what is of of of of
#                 alaska federal credit union	what of of
#                 <unk> month old lab	what of of of
#                  alex rodriguez yankees	what
#                  texas knife laws	what of
#            how many grams of fat to gain a pound	what is of of of of
#                 who are y movie	what is of of
#                 food for marijuana plants	what of
#                 kinds of egg plant	what of of
#                 i robot ro omba	what
#                actors from  o men	what is of of
#                virginia federal income tax rate	what is of of
#                 sodium laure th phosphate
#             cost of mining an o unce of gold	what is of of of
#                  california adventure park	what of
#                anxiety disorders and ad hd	what of of
#                air bag recall for honda	what of
#                number  <unk> in chinese	what is of of
#                u of a transfer credit	what is of of
#                but tern ut squash recipes	what
#                  up big boy	what of
#                <unk> honda accord mp g	what of of
#                 john paul jones musician	what of of
#               white house black market outlet store	what is of
#              how many car rots in a cup	what is is of of of
#                   allison transmission	of
#                painful injection in butt ocks	what of of
#                  pitt ock mansion
#                 <unk> ood adi airport	what of of
#                low blood pressure after surgery	what is of of
#                 ic loud for windows	what of
#                is marijuana bad for you	what is of of
#                best hand guns for women	what of of of
#                wal mart locations near me	what of of
#                 super class in java	what of of
#              how many sq ft in an acre	what is of of of
#             what kind of name is ko ep ka	what is of of of of
#                what is att mobile hotspot	what is of of of
#                 do dogs get depressed	what of of
#                cro cos mia luc ifer
#              ruby thro ated humming bird scientific name	what of of
#                  west hollywood college	what of of
#                sun str ust online banking	what of of
#                 per oid ic table	what is of
#               zy v ox patient assistance program	what of
#                   a shed	what of
#                 who is harvey milk	what of of
#                   delta review	of
#                 ps or iasis treatment	what of of
#                best paint for gour ds	what is of
#                    rewards
#             what is  meaning of c in r	what is is of of of
#                  central market lancaster	what of of
#               how to neutral ize battery acid	what is of of
#                  employee services portal	what
#                technical college of low country	what is of of
#             what does f ** * you mean ?	what is of of of
#             warren buffett net worth  2 0 <unk>	what is is of of
#                   harrisburg airport
#               2 0 <unk> h sa max	what is of of of
#                latin meaning of sil van	what of of of
#                 what det ects autism	what of of
#                dimensions of a soccer goal	what of of of
#                 florida georgia line concerts	what of of
#         how long does it take for your body to recover after birth	what is of of of
#              good questions to ask in an interview	what is of of
#                national brain tumor society address	what of
#                average cost of ky bella	what is of of
#                 3 d printing software	what of of
#                benedict c umber bat ch	what of of
#               biggest waters lide in  world	what is of of
#                 football player kills wife	what of of
#                   california condor
#                 radio city music hall	what of of
#                 largest all ig tor	what of of
#              list of companies that hire fel ons	what is of of of
#                average cost of ky bella	what is of of
#                 where do horses race	what is of
#             p inched nerve in lumb ar region symptoms	what of of of
#                 eggs in  microwave	what of of
#                 game of thrones hulu	what of of
#                  children s hospital	what of
#               coconut immune int oler ance symptoms	what of
#               tallest water slide in  world	what of of
#                 chair rail mold ing	what of of
#                  andy warhol museum
#               what is dana salary on fox	what is of of of
#                  h ives causes	what of of
#                removing smoke smell from house	what of
#                states which legal ized marijuana	what of of of
#                  cl ens ing	what of
#               how does smoking affect your body	what is of of
#                   arcadia university
#                 sal ton sea history	what is of
#                change address on pay pal	what is of of
#                 healthy baked apple slices	 of
#               how to make special brown ies	what of of of
#        what is  first  3 numbers of a social security number mean	what is of of of of
#                 sarah jessica parker movie	what of
#                bank of america credit card	what is of of
#                symptoms of bad ram memory	what of of
#                 motorcycle events in florida	what is of
#              where is my gm ail mail ?	what is of of of
#                  all ina health	what of of
#                boardwalk empire season  <unk>	what is of of
#                  shrimp pasta alfredo
#            average monthly temperatures in dest in beach , florida	what of of of
#                lord of  rings online	what is of of
#                a + federal credit union	what is of of
#                 th iam ine food	what of
#               what level does tyn amo evolve	what is of of
#                rebecca de morn ay movies	what of
#                 cancer of  bones	what of of
#                  bipolar  1	of
#                <unk> 0 <unk> area code	what is of of
#                mid s omer murders cast	what of of
#               desk tops windows  1 0	what of of
#               leonardo dic ap rio wife name	what of
#                   aks foundation
#                  letters of john	what of of
#                  gret chen carlson
#                  benefits for veterans	what
#               <unk> inches equals how many centimeter	what is of of
#               miller syndrome liss ence ph aly	what of
#               how many yards to a mile	what is of of of
#                   dream analysis
#                causes of lack of communication	what is of of
#                indianapolis white river state park	what of of
#             ic d  <unk> for thyroid nod ule	what is of of
#                 cord of wood dimensions	what of
#             what to do in g ta  <unk>	what is of of of
#                  ant rop omorphic	what of
#                tools egyptians used build pyramids	what of
#                 worlds most dangerous road	what of
#            top capital gains tax rate  2 0 <unk>	what is of of of
#                 fried chicken in chicago	what of
#                yellow teeth to white teeth	what of of of
#              how do y make cyn der blocks	what is of of
#               so res on roof of mouth	what is of of
#                 zy ce name meaning	what of
#            ac ral lent ig inous melan oma progn osis	what is of
#                 art institute of chicago	what is of
#                types of pain relie vers	what of
#                 apple id password reset	what of
#                 gall blad der location	what of
#                 great white sharks habitat	what of of
#                characteristics of observ ant people	what is of
#               red hot chili peppers scar tissue	what of
#                where is james best buried	what is of of
#                 homemade ice cream makers
#                 next gen science standards	what of
#                    adam
#                 file extension p qr	what of
#                 rental trucks to move	what of of
#                  berkshire hathaway stock
#              olympic gold medalists for  united states	what is of of
#                 le aper d sharks	what of
#             what does f ** * you mean ?	what is of of of
#               second highest mountain in  world	what is of of of
#                   stockholm syndrome	what
#                registering to vote in colorado	what of of
#                home pages for internet explorer	what is of
#             p inched nerve in lumb ar region symptoms	what of of of
#              what is brooke hy land doing now	what is of of of
#                  all tel wireless	what of
#                 free word processor programs	what of
#               western regions of east asia are	what is of of
#              when to plant daff od il bulbs	what of of of
#                colon cancer symptoms in women	what is of
#                  alec benjamin age	what
#               gardening zones in  united states	what of of of
#             dawn of  planet of  apes review	what of of of
#               how old are  rocky mountains	what is of of of of
#                  summary of justification	what of
#                  jellyfish sting treatment
#                2 00 2 toyota tacoma	what is of of
#              why is my lawn m ower smoking	what is of of
#                 list of famous volcanoes	what of of
#                paint colors for living room	what of
#                  helen keller achievements
#                how do you grill salmon	what of of
#                 snap fitness membership prices	what
#                 pro zac for dogs	what of
#                  barb ies measurements	what of
#                 drugs used for depression	what is of of
#                  clog ging shoes
#                how to freeze snow peas	what of of
#                radio city music hall address	what of of
#                <unk> 2 <unk> 2 <unk>	what is of of
#                  william howard taft	what of
#                  google chrome tv	what
#              crime rate in su w anee ga	what of of of
#                   biology movies	what of
#                low cost auto insurance nj	what is of
#                where is james best buried	what is of of of of of of of of of of of of of of of of of of
#               2 0 <unk> toyota highland er	what is of of
#                cal orie per jo ule	what of of
#                  meat loaf singer
#               dead liest plane in  world	what is of of of
#                  all tel wireless	what of of
#               wh ats  average typing speed	what of of
#                 per oid ic table	what of of
#                 definition of canceled check	what of of
#                  network storage drive	what of
#                  transitional urine cells
#                average cost of ky bella	what is of of
#                  <unk> lumber ithaca	what of
#                boy names with  t	what of of
#               powder to put on vom it	what is of of
#                  windows developer mode	what of
#                 charlotte county school board	what of of
#                   heartland award
#                 area of triangle calculator	what of of
#                best diet for belly fat	what of of of
#                professional services as job description	what is of of
#                 elm hurst memorial hospital
#               cal ories in chicken drum stick	what of of
#               irs contact number for tax returns	what is of
#          what to eat when you get your wisdom teeth taken out	what is is of of of of
#                 antibiotics follic ul itis
#                  alec benjamin age	what
#                where is  bahamas located	what is of of
#            pilot who landed  plane in  hudson river	what is of of of
#                 rick ri ordan books	what of
#                  hepatitis b vaccine	what of
#                  daylight at equator	what of
#                mac ular hole surgery recovery	what of of
#                  jellyfish sting treatment
#            e hl ers dan los vascular life expect ancy	what is of of
#                amber tamb lyn net worth	what of
#               internet explorer how to set homepage	what of of of
#                  definition of plain	what is of
#            how to get rid of a plant ers wart	what is of of of
#                   california condor
#                 next gen science standards	what of
#               2 0 <unk> miss america competition	what is of of of
#                  iceland day light
#                 apple app store iphone	what of
#                 cause of being dizzy	what of of
#            <unk> char ar st ics of all living things	what is is of of of
#                  blood pressure monitor	what of of
#                  clog ging shoes	what
#                college of  oz arks	what of of of
#               wikipedia bar ret ts es ophagus	what of
#                who is jon garland wife	what is of of
#                  history of b	what of
#                  slow cook er	what of of
#                confederate capital during civil war	what of of
#                 che vy monte carlo
#            average monthly temperatures in dest in beach , florida	what is of of
#                how do you grill salmon	what is of of
#              where is my gm ail mail ?	what is of of of
#               vitamin c lip osome encaps ulated	what
#                  fire ant reaction	what of
#               cancer ous fib ro ids symptoms	what is of of
#                   hepatitis c
#                2 2 inches to centimeters	what is of of of of
#        barry man il ow cop ac ab ana ( at  copa )	what is of of of
#                  all inclusive cruises	what of
#                  los cab os	what of
#                  2 <unk> utah	what of of
#                   australian language	what
#                  phoenix local time	what of
#                lung cancer after kidney cancer	what of of
#                   gift inventory
#              signs of a heart attack for men	what is of of of of of
#              2 0 <unk> senate primary election results	what is of of of
#               high blood pressure causes in children	what is of of of
#             author of dr jek yll and mr hyde	what is of of
#               re eb ok human rights award	what of of
#             eye injection for mac ular deg en eration	what is of of of
#                why constitutional convention is important	what of of
#               lena head ey game of thrones	what is of of
#               leonardo dic ap rio wife name	what of
#                 what are your interests	what is of of
#              old navy credit card center phone number	what is of of
#                 weather channel tyler weather	what of
#                  jack of eagles	what of
#                 zip code in netherlands	what of
#                   adolf hitler	what
#                act for america brigitte gabriel	what is of of
#              crime rate in su w anee ga	what of of
#          when is gay pride parade in nyc  2 0 <unk>	what is of of of of
#               american horror story season  <unk>	what is of of of of
#              where is my gm ail mail ?	what is of of of
#                what is  second amendment	what is of of of
#               benedict c umber bat ch age	what is of of
#             what does you triggered me mean in spanish	what is of of of of
#               concordia moor head room and board	what of of
#               when did california become a state	what is of of of
#               how many yards to a mile	what is of of
#                spiritual meaning of  <unk>	what is of of
#             denver broncos  2 0 <unk> football schedule	what is of of of
#                  ac ura cars	what of of
#                lamb orgh ini avent ador
#                 where do horses race	what is of of
#                 diabetes and neurop athy	what of
#                 cbs live stream football	what of
#                  fi u football	what of
#                 symptoms of eb ola	what of
#                 planet hollywood las vegas	what of
#                  num b feet	what of
#              old navy credit card center phone number	what is of of of of
#            can you paint over water base with oil base	what is of of of
#                 finding nem o cast	what of of
#                 examples of res umes	what of of
#                 is rice a grain	what is of of
#              signs of a heart attack for men	what is of of of of
#               can guinea pigs eat car rots	what of of of
#                  carrie grant movies	what of
#                 seismic retro fit ting	of
#                   mel gibson	what
#                federal fiscal year  <unk>	what is of of
#                what do kinetic engineer invent	what of of
#                 gas prices in cincinnati	what of
#                 mn minimum wage increase	what of
#                 <unk> month old lab	what is of of of
#                 military pay e <unk>	what is of
#            five notes of  pent atonic scale are :	what is of of
#                flower parts and ir functions	what of of

# %%
# %%time
# Out:
# CPU times: user 29.4 s, sys: 4.32 s, total: 33.7 s
# Wall time: 6.2 s
# (0.4977366469106477, 0.8276762859992753, 0.5304098378883231, 0, 0, 0)

# %%
class SeqVAE(object):
    
    def __init__(self, nb_words, max_len, embedding_matrix, dim, optimizer=RMSprop(), keep_rate_word_dropout=0.5, kl_weight=0, mode=1):
        self.dim = dim
        self.nb_words = nb_words
        self.max_len = max_len
        self.embedding_matrix = embedding_matrix
        self.optimizer = optimizer
        self.kl_weight = kl_weight
        self.keep_rate_word_dropout = keep_rate_word_dropout
        self.enableKL = True if kl_weight == 0 else False
        self.mode = mode
        self.build()
        
    def build(self):
                
        e_input = Input(shape=(self.max_len,))
        self.kl_input = Input(shape=(1,))

        embedding_layer = Embedding(self.nb_words,
                            self.embedding_matrix.shape[-1],
                            weights=[self.embedding_matrix],
                            input_length=self.max_len,
                            mask_zero=False,
                            trainable=True if self.mode == 1 else False)

        e_lstm = GRU(self.dim[0], return_state=True)
        
        _, h = e_lstm(embedding_layer(e_input))

        
        mean = Dense(self.dim[1])
        var = Dense(self.dim[1])
        
        self.h_mean = mean(h)
        self.h_log_var = var(h)
        
        z = Lambda(self.sampling)([self.h_mean, self.h_log_var])

        self.encoder = Model(e_input, self.h_mean)

        d_input = Input(shape=(self.max_len,))
        d_latent2hidden = Dense(self.dim[0], activation='relu')
        d_lstm = GRU(self.dim[0], return_sequences=True)

        softmax_layer = Dense(self.nb_words, activation="softmax")
        d_output2vocab = TimeDistributed(softmax_layer, name="rec")
        d_output2vocab_kl = TimeDistributed(softmax_layer, name="kl")
        
        dec_embedding_layer = Embedding(self.nb_words,
                                    self.embedding_matrix.shape[-1],
                                    weights=[self.embedding_matrix],
                                    input_length=self.max_len,
                                    mask_zero=False,
                                    trainable=True)

        h_z = d_latent2hidden(z)
        
        d_embed_input = dec_embedding_layer(Masking(mask_value=0.0)(d_input))
        outputs = d_lstm(d_embed_input, initial_state=[h_z])

        pred = d_output2vocab(outputs)
        pred_kl = d_output2vocab_kl(outputs)
        
        
        
#       VAE model
        self.model = Model(inputs=[e_input, d_input], outputs=[pred, pred_kl])
        self.model.compile(optimizer=self.optimizer, loss=["sparse_categorical_crossentropy", self.kl_loss])

    
    def name(self):
        
        return "seqvae_kl_%d" % self.mode if self.enableKL else "seqvae_%d" % self.mode
    
    def kl_loss(self, x, x_):
            kl_loss = - 0.5 * K.sum(1 + self.h_log_var - K.square(self.h_mean) - K.exp(self.h_log_var), axis=-1)
            return (self.kl_weight * kl_loss) 

    def word_dropout(self, x, unk_token):

        x_ = np.copy(x)
        rows, cols = np.nonzero(x_)
        for r, c in zip(rows, cols):
            if random.random() <= self.keep_rate_word_dropout:
                continue
            x_[r][c] = unk_token

        return x_
    

    def sampling(self, args):
        z_mean, z_log_var = args
        epsilon = K.random_normal(shape=(K.shape(z_mean)[0], self.dim[1]), mean=0.,\
                                  stddev=1)
    
        return z_mean + K.exp(z_log_var / 2) * epsilon

# %%
K.clear_session()
run = SeqVAE(nb_words, max_len, embedding_matrix, [200,200], optimizer=Adam(), kl_weight=0, mode=1)

# %%
eval_july(run.encoder)
# Out:
# 0.5588961284440392

# %%
q_df
# Out:
# array([[    0,     0,     0, ...,  7461,  4212,     5],
#        [    0,     0,     0, ..., 43852,  2966,  2936],
#        [    0,     0,     0, ...,  1365,    89,  6772],
#        ...,
#        [    0,     0,     0, ..., 50509,  7513,  1184],
#        [    0,     0,     0, ...,     4,  8875, 39913],
#        [    0,     0,     0, ..., 28624, 24255,   727]], dtype=int32)

# %%
y = np.expand_dims(q_df_, axis=-1)
dec_input = pad_sequences(pad_sequences(q_df_, maxlen=max_len+1, value=bpe_dict['<sos>']), maxlen=max_len, truncating="post")
for i in range(100):
    run.model.fit([q_df,dec_input] , [y, y], verbose=2, epochs=1, batch_size=256)
#     if i % 20 == 0 and i != 0:
#         kl_rate = 0.001
#         run.kl_weight = min(run.kl_weight + kl_rate, 1)
#         run.model.compile(optimizer=run.optimizer, loss=["sparse_categorical_crossentropy", run.kl_loss])
    eval_july(run.encoder)
# Out:
# Epoch 1/1
#  - 139s - loss: 2.5997 - rec_loss: 2.5997 - kl_loss: 0.0000e+00
# 0.5040583513086793
# Epoch 1/1
#  - 139s - loss: 1.8012 - rec_loss: 1.8012 - kl_loss: 0.0000e+00
# 0.49567479819431165
# Epoch 1/1
#  - 138s - loss: 1.5472 - rec_loss: 1.5472 - kl_loss: 0.0000e+00
# 0.4622072983610932
# Epoch 1/1
#  - 138s - loss: 1.3042 - rec_loss: 1.3042 - kl_loss: 0.0000e+00
# 0.4338989081367164
# Epoch 1/1
#  - 137s - loss: 1.0799 - rec_loss: 1.0799 - kl_loss: 0.0000e+00
# 0.41601992483711003
# Epoch 1/1
#  - 138s - loss: 0.8800 - rec_loss: 0.8800 - kl_loss: 0.0000e+00
# 0.40216593653405674
# Epoch 1/1
#  - 139s - loss: 0.7109 - rec_loss: 0.7109 - kl_loss: 0.0000e+00
# 0.39854121728301717
# Epoch 1/1
#  - 137s - loss: 0.5709 - rec_loss: 0.5709 - kl_loss: 0.0000e+00
# 0.3932264448842536
# Epoch 1/1
#  - 139s - loss: 0.4600 - rec_loss: 0.4600 - kl_loss: 0.0000e+00
# 0.3870444083702106
# Epoch 1/1
#  - 138s - loss: 0.3749 - rec_loss: 0.3749 - kl_loss: 0.0000e+00
# 0.38637728212768796
# Epoch 1/1
#  - 138s - loss: 0.3086 - rec_loss: 0.3086 - kl_loss: 0.0000e+00
# 0.38777824723698545
# Epoch 1/1
#  - 138s - loss: 0.2566 - rec_loss: 0.2566 - kl_loss: 0.0000e+00
# 0.38688874558028863
# Epoch 1/1
#  - 138s - loss: 0.2159 - rec_loss: 0.2159 - kl_loss: 0.0000e+00
# 0.38484289176988595
# Epoch 1/1
#  - 138s - loss: 0.1845 - rec_loss: 0.1845 - kl_loss: 0.0000e+00
# 0.38530988013965184
# Epoch 1/1
#  - 137s - loss: 0.1581 - rec_loss: 0.1581 - kl_loss: 0.0000e+00
# 0.38357535190909287
# Epoch 1/1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-66d5cd3b1a7a> in <module>()
#       2 dec_input = pad_sequences(pad_sequences(q_df_, maxlen=max_len+1, value=bpe_dict['<sos>']), maxlen=max_len, truncating="post")
#       3 for i in range(100):
# ----> 4     run.model.fit([q_df,dec_input] , [y, y], verbose=2, epochs=1, batch_size=256)
#       5 #     if i % 20 == 0 and i != 0:
#       6 #         kl_rate = 0.001
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1629                               initial_epoch=initial_epoch,
#    1630                               steps_per_epoch=steps_per_epoch,
# -> 1631                               validation_steps=validation_steps)
#    1632
#    1633     def evaluate(self, x=None, y=None,
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# /home/t-jamano/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
d_dec_input = pad_sequences(pad_sequences(d_july_, maxlen=max_len+1, value=bpe_dict['<sos>']), maxlen=max_len, truncating="post")

# %%
generate_output(run.model, bpe, [q_july, dec_input], idx=0)
# Out:
# BLEU: 0.6941
#                 cord of wood dimensions	 of  name
#                  history of b	how of justification
#                states which legal ized marijuana	 of  credit
#                 largest all ig tor	 moor stream java
#                characteristics of observ ant people	how of  in
#             what does f ** * you mean ?	how does f ** * you ? ?
#                  california adventure park	how condor stations
#                  william howard taft	 of
#               how many yards to a mile	 is get a your your
#              crime rate in su w anee ga	how does in o men ? ?
#                 snap fitness membership prices	how of in treatment
#                mid s omer murders cast	how s omer murders cast
#              easy chicken breast recipes cro ck pot	how is in in in mail
#              olympic gold medalists for  united states	how s omer in tax union
#              signs of a heart attack for men	how of in in * ? ?
#                 madness of king george	how of   name
#          when is gay pride parade in nyc  2 0 <unk>	 is gay pride pride parade nyc  2 <unk> <unk>
#                 zy ce name meaning	 v er
#                 apa inte xt citations	 class xt citations
#                  pilot training requirements	 of
#                 is rice a grain	how of  o
#                where is james best buried	how is   buried
#                  network storage drive	how of treatment
#                  h pyl ori	 class ori
#          what to eat when you get your wisdom teeth taken out	how does f  on your your you mean
#             what does you triggered me mean in spanish	how does it it your your mean mean
#                causes of lack of communication	how of in depression men
#                 rick ri ordan books	how of ordan athy
#                  carrie grant movies	how keller
#                why constitutional convention is important	how is of  a
#                <unk> honda accord mp g	 <unk> <unk> toyota lab <unk>
#                 ps or iasis treatment	how ap iasis treatment
#                 who is harvey milk	how is it milk
#               concordia moor head room and board	how moor head java
#                lamb orgh ini avent ador	how of z ar
#           google . com / andro id / dev ice manager	how . lip / canada canada canada canada
#                 annual temperature range ia	 temperature wage software
#                 motorcycle events in florida	how local hospital
#          when is gay pride parade in nyc  2 0 <unk>	 is gay pride parade parade nyc  2 <unk> <unk>
#                 file extension p qr	 extension of ing
#                painful injection in butt ocks	 of in in
#                how to freeze snow peas	 is get sees peas
#               leonardo dic ap rio wife name	how dic ap rio wife
#                 3 d printing software	how <unk> <unk> printing software
#              signs of a heart attack for men	how of in in * mean ?
#                what is att mobile hotspot	 is f ** you
#               tallest water slide in  world	how tops  in o world
#                  donna mills actress	how grant
#                  tulsa tv stations	 benjamin stations
#              where is my gm ail mail ?	how is   in mail ?
#              crime rate in su w anee ga	 from in o men ? ?
#                  pitt ock mansion	how benjamin age
#                  letters of john	how of in
#               zy v ox patient assistance program	how v ox patient assistance program
#                 finding nem o cast	how of o
#              ruby thro ated humming bird scientific name	how of   and yll
#               denny sanford premier center seating chart	how of omer standards union chart
#              1 00 grams equals how many kilograms	 <unk> <unk> <unk> equals <unk> scar board
#               miller syndrome liss ence ph aly	 s in itis
#              difference between ec g and ek g	 between gay of  and
#                average cost of ky bella	 cost temperatures ky bella
#              good questions to ask in an interview	how is f  you you you
#                  jack of eagles	how tel
#               so res on roof of mouth	how does get sees your your
#              how many car rots in a cup	 is get your after a a
#                types of pain relie vers	how of in relie men
#           what kind of dog was in turner and ho och	 is my  a   are are
#               is coal  leading energy source	how of  o world
#             what to do in g ta  <unk>	 is   g in
#              who is  director of train wreck	 is it  trailer world
#                  meat loaf singer	how loaf singer
#                  alex rodriguez yankees	 of
#                <unk> 2 <unk> 2 <unk>	 <unk> <unk> <unk> <unk> <unk>
#                  andy warhol museum	how from museum
#               high blood pressure causes in children	how is in in * you
#                 planet hollywood las vegas	how of
#                police radar how it works	how of of  o
#                 radio city music hall	how city music hall
#               powder to put on vom it	how is get a your
#               can guinea pigs eat car rots	 of my a a a
#                professional services as job description	how england as omba board
#                 seismic retro fit ting	how c in athy
#                best hand guns for women	how of  in world
#                sun str ust online banking	how hollywood  o
#              country that links north and south america	how of   of of of
#                can i gift a car	how of does a a
#                tools egyptians used build pyramids	 many for in men
#                 amit abh bachchan news	how abh bachchan treatment
#                 worlds most dangerous road	how from dangerous microwave
#               how many yards to a mile	 is get a your your
#              what is brooke hy land doing now	how does f ** you your
#                   arcadia university	how keller
#                  definition grie vance	 of treatment
#              where is my gm ail mail ?	how is   in mail ?
#                   heartland award	how of
#                  clog ging shoes	how sting treatment
#               lena head ey game of thrones	 of   of
#                average cost of ky bella	 cost temperatures ky bella
#                is my transmission going out	how is
#                national brain tumor society address	how s omer lumb table
#                  central market lancaster	how s hospital
#               should you get rental car insurance	how is get get sees your
#                 per oid ic table	how of science ic table
#                 where do horses race	how is it race
#                 homemade ice cream makers	how of cream makers
#               2 0 <unk> h sa max	how <unk> <unk> <unk> toyota ics <unk>
#                amber tamb lyn net worth	how of science credit <unk>
#                  windows developer mode	how of mode
#                  all ina health	how tel wireless
#                  american eg ale	how horror ale
#                  all tel wireless	 tel wireless
#                low blood pressure after surgery	 of in in in
#               re eb ok human rights award	how of of in
#                is marijuana bad for you	how of in in
#                rebecca de morn ay movies	how benjamin stream java board
#                federal fiscal year  <unk>	 horror season <unk> <unk>
#                   adolf hitler	how hitler
#                secretary of state of maryland	how of  standards world
#                  ac ura cars	how v er
#               david bald acci list of books	how s sharks credit  union
#              employer contribution to h sa tax able	how of of in table <unk>
#                home pages for internet explorer	how of in in
#                  los cab os	how condor stations
#               how old are  rocky mountains	 is does a rocky
#                  iceland day light	how s light
#         how long does it take for your body to recover after birth	how is does get sees your your you ? ? ?
#              how to get rid of pimp les	how is get get your your les
#                radio city music hall address	how city music hall
#                where is  bahamas located	how is   world
#                   dream analysis	how from
#              when to plant daff od il bulbs	 is gay jek od yll bulbs
#                low cost auto insurance nj	 of  dest
#              ur anus how far from  sun	 of how  in microwave world
#                   california condor	 condor
#             author of dr jek yll and mr hyde	 of  jek yll mr mr hyde
#                best diet for belly fat	how of in in
#                  gret chen carlson	 benjamin green
#              beverly hills md dark circle corre ctor	 s md dark <unk> <unk>
#                   harrisburg airport	 benjamin
#            can you paint over water base with oil base	how is get get on a a a
#            five notes of  pent atonic scale are :	 of dr  of  of of number
#                actors from  o men	how from  o men
#                   delta review	how benjamin
#                 super class in java	how class green java
#                 le aper d sharks	how city ig net
#                  slow cook er	how tel
#                and so it goes trailer	how of it o trailer
#                  benefits for veterans	how of for
#             ic d  <unk> for thyroid nod ule	how moor ig <unk> <unk> symptoms symptoms symptoms
#                great smoky mountains national park	how gold sharks murders park
#                  jellyfish sting treatment	how sting treatment
#                  lazy boy furniture	how from wireless
#                 per oid ic table	how of omer ic table
#               2 0 <unk> toyota highland er	how <unk> <unk> <unk> toyota highland
#                 bru ised heel cure	how of in room
#             what is  meaning of c in r	how is f  in in
#                dimensions of a soccer goal	how of in o
#                  hepatitis b vaccine	 sting
#                  ant rop omorphic	 of
#                 zip code in netherlands	how c treatment reset
#                how do you grill salmon	 is get get salmon
#               what is dana salary on fox	how does f ** a your
#                 food for marijuana plants	how from
#                who is jon garland wife	how is it
#                  2 <unk> utah	how <unk> <unk> <unk>
#             author of dr jek yll and mr hyde	 of  jek yll mr mr
#                ag ig ood adi airport	 england omer murders union
#                 th iam ine food	how of ine name
#                  clog ging shoes	how sting treatment
#              why is my lawn m ower smoking	 is f a a you
#               how to make special brown ies	how is get your your your
#                   australian language	how condor
#               ank yl osing sp ondyl itis	 dic ap sp ondyl itis
#                 rental trucks to move	how from singer slices
#                boardwalk empire season  <unk>	 empire season season <unk>
#                cal orie per jo ule	 of of ic
#                 great white sharks habitat	 gold sharks habitat
#                registering to vote in colorado	how of in in world
#                first national bank credit card	how of omer credit card
#               biggest waters lide in  world	how s  in world world
#             what kind of name is ko ep ka	 is my    are
#                change address on pay pal	how is
#               western regions of east asia are	how of dr    are
#                 next gen science standards	how s omer standards
#                average cost of ky bella	 cost temperatures ky bella
#               how does smoking affect your body	how is get affect your body
#                 gas prices in cincinnati	how of shoes iphone
#                 clayton county in ga	how county school cast
#                best resources for salary range	 of in o world
#                 examples of res umes	 of in board
#                 dancing with  stars	how from it o
#                  is doge dead	how of museum
#                 what are your interests	how does get race
#                 sal ton sea history	how of  o
#             how much do auto dealership drivers make ?	how is get get a your ? ?
#                  children s hospital	how condor wireless
#            average monthly temperatures in dest in beach , florida	how monthly temperatures in dest in beach ,
#                 gall blad der location	 of in tomatoes
#            ac ral lent ig inous melan oma progn osis	 ral memorial rio inous symptoms symptoms
#               1 st class letter to canada	how <unk> <unk> printing software region canada
#                lord of  rings online	how of  o
#                 apple id password reset	 hitler password iphone
#                  google chrome tv	how . tv
#                 alaska federal credit union	how s credit union
#                  christopher reeve movies	how language
#                  definition of plain	how of in
#                 diabetes and neurop athy	 c green athy
#                symptoms of bad ram memory	how follic in depression memory
#              2 0 <unk> senate primary election results	how <unk> <unk> <unk> toyota lab <unk> <unk>
#               gardening zones in  united states	how of in in world
#                 securities in stock market	how of music standards
#                  bipolar  1	 c lip
#                technical college of low country	 of  credit <unk>
#                  barb ies measurements	 of
#                  ben bridge jewelry	 of state
#               second highest mountain in  world	how s music credit standards world
#                 oven fried green tomatoes	 of green tomatoes
#                  transitional urine cells	 condor singer
#            how to get rid of a plant ers wart	 is get get a your your your
#                latin meaning of sil van	 meaning of in name
#                   allison transmission	 condor
#                 art institute of chicago	how tel wireless
#            how to manage who sees your photos on facebook	how is get on sees your photos photos facebook
#                   joey lawrence	how benjamin
#                   mel gibson	how grant
#                 antibiotics follic ul itis	 follic ul
#                 i robot ro omba	 of ro java
#                  blood pressure monitor	 of in
#                 <unk> month old lab	how <unk> <unk> <unk> lab
#                   california condor	 condor
#                 mn minimum wage increase	how class wage ch
#                u of a transfer credit	how of  credit world
#               benedict c umber bat ch age	how of umber centimeters ch
#                 native tribes of arizona	how of for o
#              list of companies that hire fel ons	how of  credit world
#               cal ories in chicken drum stick	how of in in room
#                 kinds of egg plant	 of in microwave
#                actors from  o men	how from  o men
#                air bag recall for honda	how of music  world
#                 game of thrones hulu	 of
#                  shrimp pasta alfredo	 sting treatment
#                   hepatitis c	how sting vaccine
#                  summary of justification	 of justification
#              signs of a heart attack for men	how of in in * ? ?
#                 che vy monte carlo	how of monte
#             cost of mining an o unce of gold	how of    world ,
#                 drugs used for depression	how of in depression
#                 list of famous volcanoes	 of  standards
#             dawn of  planet of  apes review	how is   in of of
#                what is  second amendment	how does f
#                    adam	how condor
#                 free word processor programs	how of it o
#                  fi u football	 c powers
#               what level does tyn amo evolve	 does does  a your
#             denver broncos  2 0 <unk> football schedule	 england ig <unk> <unk> <unk> 0
#               red hot chili peppers scar tissue	 s chili peppers tomatoes
#               irs contact number for tax returns	 c of in table
#                 next gen science standards	how s omer standards
#                   adolf hitler	how hitler
#                  kir stin powers	how s powers
#                colon cancer symptoms in women	how of after ro men
#                lies my history teacher told	how gold dr credit name
#            average monthly temperatures in dest in beach , florida	how monthly temperatures in dest in beach ,
#                cro cos mia luc ifer	 class mia luc athy
#                 football player kills wife	how horror omer standards
#                   aks foundation	how hitler
#               <unk> 2 1 silver dollar value	how <unk> <unk> <unk> <unk> <unk> <unk>
#               american horror story season  <unk>	 horror story season season <unk>
#                 ic loud for windows	how moor in java
#                 rod stewart best songs	how s season union
#                 <unk> month old lab	how <unk> <unk> <unk> lab
#                types of cer ner certifications	 of in microwave men
#              where is my gm ail mail ?	how is   in mail ?
#                what do kinetic engineer invent	 does f  o
#                best paint for gour ds	how of  o
#                 super class in java	how class green java
#                  alec benjamin age	how benjamin age
#              phar rell williams desp icable me soundtrack	how of sharks credit name ?
#                 fried chicken in chicago	how loaf cream chicago
#                   a shed	how s
#              how to screen shot on a mac	how is get your sees your your
#                 eggs in  microwave	 loaf in microwave
#                 area of triangle calculator	 of triangle athy
#                  h ives causes	how class ing
#               bank of america short sale package	how s state credit union
#                 great white sharks habitat	 gold sharks habitat
#                 cold well banker realty	 of  standards
#            e hl ers dan los vascular life expect ancy	how class umber ic ch <unk> <unk> ancy ancy
#              old navy credit card center phone number	how s credit card union
#                  texas knife laws	how s laws
#                 eggs in  microwave	 loaf in microwave
#               <unk> inches equals how many centimeter	 <unk> <unk> equals equals in board
#                 dish network remote control	how abh remote
#                  west hollywood college	how s er
#                  helen keller achievements	how condor achievements
#                mac ular hole surgery recovery	how of in in
#               coconut immune int oler ance symptoms	how of in in table
#              how many sq ft in an acre	 is get in in in your
#             p inched nerve in lumb ar region symptoms	 of nerve in lumb ar <unk> <unk>
#                   biology movies	how sting
#                spiritual meaning of  <unk>	 s in credit <unk>
#                secretary of state of michigan	how of  credit world
#                  fire ant reaction	how of
#                 elm hurst memorial hospital	how class memorial hospital
#            pilot who landed  plane in  hudson river	how of     of of of
#               vitamin c lip osome encaps ulated	how c lip osome encaps
#                  im rl definition	how of umber
#                and so it goes trailer	how of it o trailer
#                  up big boy	how s er
#                 weather channel tyler weather	how of  credit
#        what is  first  3 numbers of a social security number mean	how is f   in in in mean mean mean mean
#                confederate capital during civil war	how s omer credit
#                 chair rail mold ing	how rail mold
#                but tern ut squash recipes	 is  state
#                a + federal credit union	how s of credit union
#               when did california become a state	how is dr
#                 charlotte county school board	how of school cast
#               wikipedia bar ret ts es ophagus	 of ig   <unk>
#               2 0 <unk> miss america competition	 <unk> <unk> <unk> toyota lab <unk>
#                 drugs used for depression	how of in depression
#               white house black market outlet store	how city music credit standards
#               cleaning st ains from vinyl siding	 of in in microwave
#                 apple app store iphone	 app treatment
#           difference between whe y protein and whe y protein isolate	 between gay parade protein and and protein isolate isolate
#                   red symbolism	how condor
#                  <unk> lumber ithaca	 <unk> <unk> ithaca
#             what does f ** * you mean ?	how does f ** * you ? ?
#              how long spaghetti sauce in refriger ator	how is does a a a your
#                paint colors for living room	how of for microwave men
#                  kinds of arthritis	 of in
#                 who are y movie	how does get race
#            top capital gains tax rate  2 0 <unk>	 cost sharks ky  2 <unk> <unk> <unk>
#                 symptoms of eb ola	 to in
#                yellow teeth to white teeth	how is in in
#                 pro zac for dogs	how of in cincinnati
#                 bey once blow lyrics	how of blow
#              old navy credit card center phone number	how s credit card
#               dead liest plane in  world	how from  in men homepage
#                  car salesman kidnapped	 s age
#              which is a good conductor of electricity	 of    world ?
#                2 2 inches to centimeters	 <unk> <unk> <unk> <unk> <unk>
#        barry man il ow cop ac ab ana ( at  copa )	 s sharks credit bella  , , ( at
#                act for america brigitte gabriel	how of  o
#                  all inclusive cruises	how tel treatment
#                2 00 2 toyota tacoma	 <unk> <unk> <unk> <unk> <unk>
#                  berkshire hathaway stock	how of er
#                 what det ects autism	how does a a
#                  alec benjamin age	how benjamin age
#                mid s omer murders cast	how s omer murders cast
#               acute gall blad der attack symptoms	 ap in ar table symptoms
#               leonardo dic ap rio wife name	how dic ap rio wife
#                 cp ap machines reviews	how ap rio name
#                  daylight at equator	 of equator
#                where is james best buried	how is   buried
#               leonardo dic ap rio wife name	how dic ap rio wife
#                college of  oz arks	how of  credit
#                 military pay e <unk>	 s season <unk>
#                  employee services portal	 of hospital
#                  num b feet	how of movies
#                benedict c umber bat ch	how of umber centimeters ch
#             average cost of car  2 0 <unk>	 cost temperatures ky bella <unk> <unk> <unk>
#               can guinea pigs eat car rots	 of pigs a a a
#                 where do horses race	how is it race
#                  <unk> area code	how <unk> <unk> in board
#                virginia federal income tax rate	 s credit union
#               wh ats  average typing speed	how of science credit  <unk>
#                 florida georgia line concerts	how s music standards
#               why doesn ' t chrome open	how is get a on *
#                 do dogs get depressed	how does get depressed
#                 cbs live stream football	how s stream
#                 sodium laure th phosphate	 ap green ch
#             eye injection for mac ular deg en eration	 of in in * mean hyde
#                flower parts and ir functions	how of in world
#            pilot who landed  plane in  hudson river	how of     of of of
#                   gift inventory	 condor
#                    rewards	how loaf
#               desk tops windows  1 0	 cost head murders <unk>
#                 cause of being dizzy	 of in cast
#                 healthy baked apple slices	 of in slices
#                bank of america credit card	how s state credit union
#                average cost of ky bella	 cost temperatures ky bella
#                 cancer of  bones	how c in cast
#                boy names with  t	 from from o microwave
#             what does f ** * you mean ?	how does f ** * you ? ?
#                  phoenix local time	how condor
#                   stockholm syndrome	 condor
#                  all tel wireless	 tel wireless
#                <unk> 0 <unk> area code	how <unk> <unk> <unk> toyota board
#                great smoky mountains national park	how gold sharks murders park
#                   hungry hearts	how condor
#               american horror story season  <unk>	 horror story season worth <unk>
#                 definition of canceled check	 of in
#               cancer ous fib ro ids symptoms	 c in ro ids
#                  jellyfish sting treatment	how sting treatment
#             p inched nerve in lumb ar region symptoms	 of in in lumb ar <unk> region
#                bridge with locks in paris	how s  in
#                home pages for internet explorer	how of in in
#                how do you grill salmon	 is get get salmon
#            <unk> char ar st ics of all living things	how <unk> <unk> toyota sa <unk> <unk> life
#               how to neutral ize battery acid	how is get your your your
#                 ad t customer service	how tel customer cast
#                lung cancer after kidney cancer	 c in kidney siding
#             what to do in g ta  <unk>	 is   g ta  <unk>
#                anxiety disorders and ad hd	 of in in mail
#                   bio examples	how sting
#                indianapolis white river state park	how s omer murders
#            how many grams of fat to gain a pound	 is get bad in your your mean ?
#                 <unk> bmw z 3	 <unk> <unk> <unk> <unk>
#                 john paul jones musician	how language wireless
#            average monthly temperatures in dest in beach , florida	how monthly temperatures in dest in beach ,
#              what level does tir to uga evolve	how does does  on you
#                 calc u ium carbonate	 c ium
#                removing smoke smell from house	how of bad in
#                  family feud halloween	how county
#                number  <unk> in chinese	how of <unk> <unk> software
#                  cl ens ing	 of
#                kendall jenn er last name	how of sharks credit
#               internet explorer how to set homepage	 of for for microwave
#             warren buffett net worth  2 0 <unk>	 horror story season <unk> <unk> <unk> <unk>
#                wal mart locations near me	how of stock java
#                 which muscle open jaw	 of in
#                 zoe z ald ana	 of ald
#                 birmingham england botanical gardens	how horror omer sa
#                   employment agency	how agency
#              how do y make cyn der blocks	 is get your sees your body
#                 sarah jessica parker movie	how from

# %%
def generate_output(model, bpe, x, nrows=100000, idx=None):

    gen_x = np.argmax(model.predict(x), axis=-1) if idx == None else np.argmax(model.predict(x)[idx], axis=-1)
    bleu = []
    results = []
    count = 0
    for i, k in zip(gen_x, x[0]):
        gen_x = " ".join([bpe.index2word[t] for t in i])
        real_x = " ".join([bpe.index2word[t] for t in k])

        bleu.append(sentence_bleu(real_x, gen_x))
        
        real_x = real_x.replace("▁the", "")
        real_x = real_x.replace("▁","")
        gen_x = gen_x.replace("▁the", "")
        gen_x = gen_x.replace("▁","")
        
        if count > nrows:
            break
        count = count + 1
        results.append("%s\t%s" % (real_x, gen_x))
        
    
    print("BLEU: %.4f" % np.mean(bleu))
    idx = np.arange(len(results))
    shuffle(idx)
    for i in idx[:nrows]:
        print(results[i])

# %%
# import os
# os.environ["THEANO_FLAGS"] = "mode=FAST_COMPILE,device=cpu,floatX=float32"

import matplotlib as mpl

# This line allows mpl to run with no DISPLAY defined
mpl.use('Agg')

from keras.layers import Dense, Reshape, Flatten, Input, merge
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras_adversarial.legacy import l1l2
import keras.backend as K
import pandas as pd
import numpy as np
from keras_adversarial.image_grid_callback import ImageGridCallback

from keras_adversarial import AdversarialModel, fix_names, n_choice
from keras_adversarial import AdversarialOptimizerSimultaneous, normal_latent_sampling
from keras.layers import LeakyReLU, Activation
import os
import numpy as np
from keras.datasets import mnist


def mnist_process(x):
    x = x.astype(np.float32) / 255.0
    return x


def mnist_data():
    (xtrain, ytrain), (xtest, ytest) = mnist.load_data()
    return mnist_process(xtrain), mnist_process(xtest)


def model_generator(latent_dim, input_shape, hidden_dim=512, reg=lambda: l1l2(1e-7, 0)):
    return Sequential([
        Dense(hidden_dim, name="generator_h1", input_dim=latent_dim, W_regularizer=reg()),
        LeakyReLU(0.2),
        Dense(hidden_dim, name="generator_h2", W_regularizer=reg()),
        LeakyReLU(0.2),
        Dense(np.prod(input_shape), name="generator_x_flat", W_regularizer=reg()),
        Activation('sigmoid'),
        Reshape(input_shape, name="generator_x")],
        name="generator")


def model_encoder(latent_dim, input_shape, hidden_dim=512, reg=lambda: l1l2(1e-7, 0)):
    x = Input(input_shape, name="x")
    h = Flatten()(x)
    h = Dense(hidden_dim, name="encoder_h1", W_regularizer=reg())(h)
    h = LeakyReLU(0.2)(h)
    h = Dense(hidden_dim, name="encoder_h2", W_regularizer=reg())(h)
    h = LeakyReLU(0.2)(h)
    mu = Dense(latent_dim, name="encoder_mu", W_regularizer=reg())(h)
    log_sigma_sq = Dense(latent_dim, name="encoder_log_sigma_sq", W_regularizer=reg())(h)
    z = merge([mu, log_sigma_sq], mode=lambda p: p[0] + K.random_normal(K.shape(p[0])) * K.exp(p[1] / 2),
              output_shape=lambda p: p[0])
    return Model(x, z, name="encoder")


def model_discriminator(latent_dim, output_dim=1, hidden_dim=512,
                        reg=lambda: l1l2(1e-7, 1e-7)):
    z = Input((latent_dim,))
    h = z
    h = Dense(hidden_dim, name="discriminator_h1", W_regularizer=reg())(h)
    h = LeakyReLU(0.2)(h)
    h = Dense(hidden_dim, name="discriminator_h2", W_regularizer=reg())(h)
    h = LeakyReLU(0.2)(h)
    y = Dense(output_dim, name="discriminator_y", activation="sigmoid", W_regularizer=reg())(h)
    return Model(z, y)


def example_aae(path, adversarial_optimizer):
    # z \in R^100
    latent_dim = 100
    # x \in R^{28x28}
    input_shape = (28, 28)

    # generator (z -> x)
    generator = model_generator(latent_dim, input_shape)
    # encoder (x ->z)
    encoder = model_encoder(latent_dim, input_shape)
    # autoencoder (x -> x')
    autoencoder = Model(encoder.inputs, generator(encoder(encoder.inputs)))
    # discriminator (z -> y)
    discriminator = model_discriminator(latent_dim)

    # assemple AAE
    x = encoder.inputs[0]
    z = encoder(x)
    xpred = generator(z)
    zreal = normal_latent_sampling((latent_dim,))(x)
    yreal = discriminator(zreal)
    yfake = discriminator(z)
    aae = Model(x, fix_names([xpred, yfake, yreal], ["xpred", "yfake", "yreal"]))

    # build adversarial model
    generative_params = generator.trainable_weights + encoder.trainable_weights
    model = AdversarialModel(base_model=aae,
                             player_params=[generative_params, discriminator.trainable_weights],
                             player_names=["generator", "discriminator"])
    model.adversarial_compile(adversarial_optimizer=adversarial_optimizer,
                              player_optimizers=[Adam(1e-4, decay=1e-4), Adam(1e-3, decay=1e-4)],
                              loss={"yfake": "binary_crossentropy", "yreal": "binary_crossentropy",
                                    "xpred": "mean_squared_error"},
                              player_compile_kwargs=[{"loss_weights": {"yfake": 1e-2, "yreal": 1e-2, "xpred": 1}}] * 2)

    # load mnist data
    xtrain, xtest = mnist_data()

    # callback for image grid of generated samples
    def generator_sampler():
        zsamples = np.random.normal(size=(10 * 10, latent_dim))
        return generator.predict(zsamples).reshape((10, 10, 28, 28))

    generator_cb = ImageGridCallback(os.path.join(path, "generated-epoch-{:03d}.png"), generator_sampler)

    # callback for image grid of autoencoded samples
    def autoencoder_sampler():
        xsamples = n_choice(xtest, 10)
        xrep = np.repeat(xsamples, 9, axis=0)
        xgen = autoencoder.predict(xrep).reshape((10, 9, 28, 28))
        xsamples = xsamples.reshape((10, 1, 28, 28))
        samples = np.concatenate((xsamples, xgen), axis=1)
        return samples

    autoencoder_cb = ImageGridCallback(os.path.join(path, "autoencoded-epoch-{:03d}.png"), autoencoder_sampler)

    # train network
    # generator, discriminator; pred, yfake, yreal
    n = xtrain.shape[0]
    y = [xtrain, np.ones((n, 1)), np.zeros((n, 1)), xtrain, np.zeros((n, 1)), np.ones((n, 1))]
    ntest = xtest.shape[0]
    ytest = [xtest, np.ones((ntest, 1)), np.zeros((ntest, 1)), xtest, np.zeros((ntest, 1)), np.ones((ntest, 1))]
    history = model.fit(x=xtrain, y=y, validation_data=(xtest, ytest), callbacks=[generator_cb, autoencoder_cb],
                        nb_epoch=100, batch_size=256, verbose=2)



def main():
    example_aae("output/aae", AdversarialOptimizerSimultaneous())


main()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 22s - loss: 0.2440 - generator_loss: 0.1262 - generator_xpred_loss: 0.0937 - generator_yfake_loss: 1.1283 - generator_yreal_loss: 0.9786 - discriminator_loss: 0.1178 - discriminator_xpred_loss: 0.0937 - discriminator_yfake_loss: 0.6023 - discriminator_yreal_loss: 0.6644 - val_loss: 0.1780 - val_generator_loss: 0.0908 - val_generator_xpred_loss: 0.0650 - val_generator_yfake_loss: 0.9078 - val_generator_yreal_loss: 0.7378 - val_discriminator_loss: 0.0872 - val_discriminator_xpred_loss: 0.0650 - val_discriminator_yfake_loss: 0.5917 - val_discriminator_yreal_loss: 0.6972
# Epoch 2/100
#  - 19s - loss: 0.1694 - generator_loss: 0.0881 - generator_xpred_loss: 0.0605 - generator_yfake_loss: 0.9969 - generator_yreal_loss: 0.9262 - discriminator_loss: 0.0813 - discriminator_xpred_loss: 0.0605 - discriminator_yfake_loss: 0.6218 - discriminator_yreal_loss: 0.6256 - val_loss: 0.1583 - val_generator_loss: 0.0852 - val_generator_xpred_loss: 0.0543 - val_generator_yfake_loss: 1.1503 - val_generator_yreal_loss: 1.1676 - val_discriminator_loss: 0.0732 - val_discriminator_xpred_loss: 0.0543 - val_discriminator_yfake_loss: 0.5776 - val_discriminator_yreal_loss: 0.5415
# Epoch 3/100
#  - 19s - loss: 0.1541 - generator_loss: 0.0847 - generator_xpred_loss: 0.0509 - generator_yfake_loss: 1.3203 - generator_yreal_loss: 1.2856 - discriminator_loss: 0.0694 - discriminator_xpred_loss: 0.0509 - discriminator_yfake_loss: 0.5387 - discriminator_yreal_loss: 0.5386 - val_loss: 0.1468 - val_generator_loss: 0.0833 - val_generator_xpred_loss: 0.0466 - val_generator_yfake_loss: 1.4879 - val_generator_yreal_loss: 1.4129 - val_discriminator_loss: 0.0635 - val_discriminator_xpred_loss: 0.0466 - val_discriminator_yfake_loss: 0.4535 - val_discriminator_yreal_loss: 0.4658
# Epoch 4/100
# Epoch 9/100
#  - 20s - loss: 0.1134 - generator_loss: 0.0631 - generator_xpred_loss: 0.0318 - generator_yfake_loss: 1.2068 - generator_yreal_loss: 1.1945 - discriminator_loss: 0.0503 - discriminator_xpred_loss: 0.0318 - discriminator_yfake_loss: 0.5591 - discriminator_yreal_loss: 0.5573 - val_loss: 0.1103 - val_generator_loss: 0.0600 - val_generator_xpred_loss: 0.0311 - val_generator_yfake_loss: 1.0945 - val_generator_yreal_loss: 1.0778 - val_discriminator_loss: 0.0503 - val_discriminator_xpred_loss: 0.0311 - val_discriminator_yfake_loss: 0.6069 - val_discriminator_yreal_loss: 0.5998
# Epoch 10/100
#  - 20s - loss: 0.1096 - generator_loss: 0.0608 - generator_xpred_loss: 0.0304 - generator_yfake_loss: 1.1677 - generator_yreal_loss: 1.1645 - discriminator_loss: 0.0487 - discriminator_xpred_loss: 0.0304 - discriminator_yfake_loss: 0.5618 - discriminator_yreal_loss: 0.5579 - val_loss: 0.1080 - val_generator_loss: 0.0601 - val_generator_xpred_loss: 0.0292 - val_generator_yfake_loss: 1.2010 - val_generator_yreal_loss: 1.1726 - val_discriminator_loss: 0.0479 - val_discriminator_xpred_loss: 0.0292 - val_discriminator_yfake_loss: 0.5692 - val_discriminator_yreal_loss: 0.5887
# Epoch 11/100
#  - 19s - loss: 0.1072 - generator_loss: 0.0596 - generator_xpred_loss: 0.0291 - generator_yfake_loss: 1.1667 - generator_yreal_loss: 1.1662 - discriminator_loss: 0.0476 - discriminator_xpred_loss: 0.0291 - discriminator_yfake_loss: 0.5660 - discriminator_yreal_loss: 0.5635 - val_loss: 0.1046 - val_generator_loss: 0.0577 - val_generator_xpred_loss: 0.0279 - val_generator_yfake_loss: 1.1545 - val_generator_yreal_loss: 1.1112 - val_discriminator_loss: 0.0469 - val_discriminator_xpred_loss: 0.0279 - val_discriminator_yfake_loss: 0.5656 - val_discriminator_yreal_loss: 0.6197
# Epoch 12/100
#  - 19s - loss: 0.1045 - generator_loss: 0.0582 - generator_xpred_loss: 0.0279 - generator_yfake_loss: 1.1595 - generator_yreal_loss: 1.1550 - discriminator_loss: 0.0463 - discriminator_xpred_loss: 0.0279 - discriminator_yfake_loss: 0.5654 - discriminator_yreal_loss: 0.5652 - val_loss: 0.1026 - val_generator_loss: 0.0572 - val_generator_xpred_loss: 0.0270 - val_generator_yfake_loss: 1.1790 - val_generator_yreal_loss: 1.1284 - val_discriminator_loss: 0.0454 - val_discriminator_xpred_loss: 0.0270 - val_discriminator_yfake_loss: 0.5343 - val_discriminator_yreal_loss: 0.5841
# Epoch 13/100
#  - 20s - loss: 0.1030 - generator_loss: 0.0577 - generator_xpred_loss: 0.0270 - generator_yfake_loss: 1.1816 - generator_yreal_loss: 1.1778 - discriminator_loss: 0.0453 - discriminator_xpred_loss: 0.0270 - discriminator_yfake_loss: 0.5587 - discriminator_yreal_loss: 0.5629 - val_loss: 0.0993 - val_generator_loss: 0.0548 - val_generator_xpred_loss: 0.0261 - val_generator_yfake_loss: 1.1368 - val_generator_yreal_loss: 1.0212 - val_discriminator_loss: 0.0445 - val_discriminator_xpred_loss: 0.0261 - val_discriminator_yfake_loss: 0.5243 - val_discriminator_yreal_loss: 0.6073
# Epoch 14/100
#  - 19s - loss: 0.1006 - generator_loss: 0.0560 - generator_xpred_loss: 0.0262 - generator_yfake_loss: 1.1464 - generator_yreal_loss: 1.1386 - discriminator_loss: 0.0446 - discriminator_xpred_loss: 0.0262 - discriminator_yfake_loss: 0.5670 - discriminator_yreal_loss: 0.5750 - val_loss: 0.0947 - val_generator_loss: 0.0520 - val_generator_xpred_loss: 0.0247 - val_generator_yfake_loss: 1.0004 - val_generator_yreal_loss: 1.0247 - val_discriminator_loss: 0.0428 - val_discriminator_xpred_loss: 0.0247 - val_discriminator_yfake_loss: 0.5670 - val_discriminator_yreal_loss: 0.5415
# Epoch 15/100
#  - 19s - loss: 0.0969 - generator_loss: 0.0536 - generator_xpred_loss: 0.0250 - generator_yfake_loss: 1.0879 - generator_yreal_loss: 1.0835 - discriminator_loss: 0.0433 - discriminator_xpred_loss: 0.0250 - discriminator_yfake_loss: 0.5692 - discriminator_yreal_loss: 0.5768 - val_loss: 0.0943 - val_generator_loss: 0.0517 - val_generator_xpred_loss: 0.0242 - val_generator_yfake_loss: 1.0434 - val_generator_yreal_loss: 1.0149 - val_discriminator_loss: 0.0427 - val_discriminator_xpred_loss: 0.0242 - val_discriminator_yfake_loss: 0.5741 - val_discriminator_yreal_loss: 0.5829
# Epoch 16/100
#  - 20s - loss: 0.0951 - generator_loss: 0.0525 - generator_xpred_loss: 0.0242 - generator_yfake_loss: 1.0762 - generator_yreal_loss: 1.0652 - discriminator_loss: 0.0427 - discriminator_xpred_loss: 0.0242 - discriminator_yfake_loss: 0.5778 - discriminator_yreal_loss: 0.5834 - val_loss: 0.0932 - val_generator_loss: 0.0501 - val_generator_xpred_loss: 0.0236 - val_generator_yfake_loss: 0.9820 - val_generator_yreal_loss: 0.9876 - val_discriminator_loss: 0.0430 - val_discriminator_xpred_loss: 0.0236 - val_discriminator_yfake_loss: 0.6331 - val_discriminator_yreal_loss: 0.6285
# Epoch 17/100
#  - 19s - loss: 0.0943 - generator_loss: 0.0522 - generator_xpred_loss: 0.0236 - generator_yfake_loss: 1.0812 - generator_yreal_loss: 1.0986 - discriminator_loss: 0.0421 - discriminator_xpred_loss: 0.0236 - discriminator_yfake_loss: 0.5825 - discriminator_yreal_loss: 0.5839 - val_loss: 0.0922 - val_generator_loss: 0.0507 - val_generator_xpred_loss: 0.0228 - val_generator_yfake_loss: 1.0500 - val_generator_yreal_loss: 1.0577 - val_discriminator_loss: 0.0415 - val_discriminator_xpred_loss: 0.0228 - val_discriminator_yfake_loss: 0.5996 - val_discriminator_yreal_loss: 0.5820
# Epoch 18/100
#  - 19s - loss: 0.0926 - generator_loss: 0.0512 - generator_xpred_loss: 0.0229 - generator_yfake_loss: 1.0874 - generator_yreal_loss: 1.0679 - discriminator_loss: 0.0414 - discriminator_xpred_loss: 0.0229 - discriminator_yfake_loss: 0.5776 - discriminator_yreal_loss: 0.5950 - val_loss: 0.0923 - val_generator_loss: 0.0520 - val_generator_xpred_loss: 0.0224 - val_generator_yfake_loss: 1.1050 - val_generator_yreal_loss: 1.1798 - val_discriminator_loss: 0.0402 - val_discriminator_xpred_loss: 0.0224 - val_discriminator_yfake_loss: 0.5603 - val_discriminator_yreal_loss: 0.5432
# Epoch 19/100
#  - 19s - loss: 0.0906 - generator_loss: 0.0498 - generator_xpred_loss: 0.0222 - generator_yfake_loss: 1.0308 - generator_yreal_loss: 1.0555 - discriminator_loss: 0.0408 - discriminator_xpred_loss: 0.0222 - discriminator_yfake_loss: 0.5841 - discriminator_yreal_loss: 0.5963 - val_loss: 0.0893 - val_generator_loss: 0.0502 - val_generator_xpred_loss: 0.0214 - val_generator_yfake_loss: 1.1035 - val_generator_yreal_loss: 1.1122 - val_discriminator_loss: 0.0391 - val_discriminator_xpred_loss: 0.0214 - val_discriminator_yfake_loss: 0.5606 - val_discriminator_yreal_loss: 0.5420
# Epoch 20/100
#  - 20s - loss: 0.0898 - generator_loss: 0.0497 - generator_xpred_loss: 0.0216 - generator_yfake_loss: 1.0591 - generator_yreal_loss: 1.0698 - discriminator_loss: 0.0402 - discriminator_xpred_loss: 0.0216 - discriminator_yfake_loss: 0.5855 - discriminator_yreal_loss: 0.5950 - val_loss: 0.0864 - val_generator_loss: 0.0463 - val_generator_xpred_loss: 0.0209 - val_generator_yfake_loss: 0.9953 - val_generator_yreal_loss: 0.8749 - val_discriminator_loss: 0.0402 - val_discriminator_xpred_loss: 0.0209 - val_discriminator_yfake_loss: 0.5853 - val_discriminator_yreal_loss: 0.6727
# Epoch 21/100
#  - 19s - loss: 0.0870 - generator_loss: 0.0477 - generator_xpred_loss: 0.0209 - generator_yfake_loss: 1.0124 - generator_yreal_loss: 1.0099 - discriminator_loss: 0.0393 - discriminator_xpred_loss: 0.0209 - discriminator_yfake_loss: 0.5858 - discriminator_yreal_loss: 0.5941 - val_loss: 0.0867 - val_generator_loss: 0.0480 - val_generator_xpred_loss: 0.0202 - val_generator_yfake_loss: 1.0875 - val_generator_yreal_loss: 1.0398 - val_discriminator_loss: 0.0386 - val_discriminator_xpred_loss: 0.0202 - val_discriminator_yfake_loss: 0.5737 - val_discriminator_yreal_loss: 0.6102
# Epoch 22/100
#  - 19s - loss: 0.0872 - generator_loss: 0.0482 - generator_xpred_loss: 0.0206 - generator_yfake_loss: 1.0459 - generator_yreal_loss: 1.0580 - discriminator_loss: 0.0390 - discriminator_xpred_loss: 0.0206 - discriminator_yfake_loss: 0.5832 - discriminator_yreal_loss: 0.5980 - val_loss: 0.0863 - val_generator_loss: 0.0485 - val_generator_xpred_loss: 0.0198 - val_generator_yfake_loss: 1.1281 - val_generator_yreal_loss: 1.0820 - val_discriminator_loss: 0.0378 - val_discriminator_xpred_loss: 0.0198 - val_discriminator_yfake_loss: 0.5550 - val_discriminator_yreal_loss: 0.5871
# Epoch 42/100
#  - 19s - loss: 0.0778 - generator_loss: 0.0431 - generator_xpred_loss: 0.0167 - generator_yfake_loss: 0.9988 - generator_yreal_loss: 1.0311 - discriminator_loss: 0.0347 - discriminator_xpred_loss: 0.0167 - discriminator_yfake_loss: 0.5950 - discriminator_yreal_loss: 0.6005 - val_loss: 0.0769 - val_generator_loss: 0.0426 - val_generator_xpred_loss: 0.0160 - val_generator_yfake_loss: 1.0053 - val_generator_yreal_loss: 1.0554 - val_discriminator_loss: 0.0343 - val_discriminator_xpred_loss: 0.0160 - val_discriminator_yfake_loss: 0.6259 - val_discriminator_yreal_loss: 0.6071
# Epoch 43/100
#  - 20s - loss: 0.0766 - generator_loss: 0.0422 - generator_xpred_loss: 0.0165 - generator_yfake_loss: 0.9781 - generator_yreal_loss: 0.9994 - discriminator_loss: 0.0344 - discriminator_xpred_loss: 0.0165 - discriminator_yfake_loss: 0.5912 - discriminator_yreal_loss: 0.5978 - val_loss: 0.0756 - val_generator_loss: 0.0413 - val_generator_xpred_loss: 0.0160 - val_generator_yfake_loss: 1.0381 - val_generator_yreal_loss: 0.8996 - val_discriminator_loss: 0.0343 - val_discriminator_xpred_loss: 0.0160 - val_discriminator_yfake_loss: 0.5806 - val_discriminator_yreal_loss: 0.6558
# Epoch 44/100
#  - 20s - loss: 0.0764 - generator_loss: 0.0422 - generator_xpred_loss: 0.0164 - generator_yfake_loss: 0.9766 - generator_yreal_loss: 1.0031 - discriminator_loss: 0.0342 - discriminator_xpred_loss: 0.0164 - discriminator_yfake_loss: 0.5906 - discriminator_yreal_loss: 0.5949 - val_loss: 0.0759 - val_generator_loss: 0.0422 - val_generator_xpred_loss: 0.0159 - val_generator_yfake_loss: 1.0054 - val_generator_yreal_loss: 1.0254 - val_discriminator_loss: 0.0337 - val_discriminator_xpred_loss: 0.0159 - val_discriminator_yfake_loss: 0.5980 - val_discriminator_yreal_loss: 0.5886
# Epoch 45/100
#  - 19s - loss: 0.0767 - generator_loss: 0.0423 - generator_xpred_loss: 0.0165 - generator_yfake_loss: 0.9836 - generator_yreal_loss: 1.0079 - discriminator_loss: 0.0344 - discriminator_xpred_loss: 0.0165 - discriminator_yfake_loss: 0.5938 - discriminator_yreal_loss: 0.6007 - val_loss: 0.0755 - val_generator_loss: 0.0420 - val_generator_xpred_loss: 0.0157 - val_generator_yfake_loss: 1.0156 - val_generator_yreal_loss: 1.0152 - val_discriminator_loss: 0.0335 - val_discriminator_xpred_loss: 0.0157 - val_discriminator_yfake_loss: 0.5752 - val_discriminator_yreal_loss: 0.6060
# Epoch 46/100
# Epoch 56/100
#  - 19s - loss: 0.0740 - generator_loss: 0.0408 - generator_xpred_loss: 0.0155 - generator_yfake_loss: 0.9684 - generator_yreal_loss: 0.9830 - discriminator_loss: 0.0332 - discriminator_xpred_loss: 0.0155 - discriminator_yfake_loss: 0.5884 - discriminator_yreal_loss: 0.6019 - val_loss: 0.0738 - val_generator_loss: 0.0413 - val_generator_xpred_loss: 0.0154 - val_generator_yfake_loss: 1.0235 - val_generator_yreal_loss: 0.9925 - val_discriminator_loss: 0.0325 - val_discriminator_xpred_loss: 0.0154 - val_discriminator_yfake_loss: 0.5554 - val_discriminator_yreal_loss: 0.5821
# Epoch 57/100
#  - 19s - loss: 0.0747 - generator_loss: 0.0413 - generator_xpred_loss: 0.0157 - generator_yfake_loss: 0.9689 - generator_yreal_loss: 1.0170 - discriminator_loss: 0.0334 - discriminator_xpred_loss: 0.0157 - discriminator_yfake_loss: 0.5966 - discriminator_yreal_loss: 0.5957 - val_loss: 0.0728 - val_generator_loss: 0.0398 - val_generator_xpred_loss: 0.0150 - val_generator_yfake_loss: 1.0065 - val_generator_yreal_loss: 0.8895 - val_discriminator_loss: 0.0331 - val_discriminator_xpred_loss: 0.0150 - val_discriminator_yfake_loss: 0.5682 - val_discriminator_yreal_loss: 0.6589
# Epoch 58/100
#  - 19s - loss: 0.0740 - generator_loss: 0.0408 - generator_xpred_loss: 0.0155 - generator_yfake_loss: 0.9693 - generator_yreal_loss: 0.9883 - discriminator_loss: 0.0331 - discriminator_xpred_loss: 0.0155 - discriminator_yfake_loss: 0.5877 - discriminator_yreal_loss: 0.5994 - val_loss: 0.0759 - val_generator_loss: 0.0434 - val_generator_xpred_loss: 0.0153 - val_generator_yfake_loss: 1.0452 - val_generator_yreal_loss: 1.1702 - val_discriminator_loss: 0.0325 - val_discriminator_xpred_loss: 0.0153 - val_discriminator_yfake_loss: 0.5715 - val_discriminator_yreal_loss: 0.5603
# Epoch 59/100
#  - 19s - loss: 0.0745 - generator_loss: 0.0410 - generator_xpred_loss: 0.0156 - generator_yfake_loss: 0.9727 - generator_yreal_loss: 0.9885 - discriminator_loss: 0.0335 - discriminator_xpred_loss: 0.0156 - discriminator_yfake_loss: 0.5998 - discriminator_yreal_loss: 0.6084 - val_loss: 0.0754 - val_generator_loss: 0.0424 - val_generator_xpred_loss: 0.0159 - val_generator_yfake_loss: 1.0362 - val_generator_yreal_loss: 1.0196 - val_discriminator_loss: 0.0330 - val_discriminator_xpred_loss: 0.0159 - val_discriminator_yfake_loss: 0.5227 - val_discriminator_yreal_loss: 0.5994
# Epoch 60/100
#  - 19s - loss: 0.0750 - generator_loss: 0.0415 - generator_xpred_loss: 0.0156 - generator_yfake_loss: 0.9859 - generator_yreal_loss: 1.0184 - discriminator_loss: 0.0335 - discriminator_xpred_loss: 0.0156 - discriminator_yfake_loss: 0.5967 - discriminator_yreal_loss: 0.6032 - val_loss: 0.0736 - val_generator_loss: 0.0407 - val_generator_xpred_loss: 0.0154 - val_generator_yfake_loss: 0.8916 - val_generator_yreal_loss: 1.0617 - val_discriminator_loss: 0.0329 - val_discriminator_xpred_loss: 0.0154 - val_discriminator_yfake_loss: 0.6267 - val_discriminator_yreal_loss: 0.5457
# Epoch 61/100
#  - 19s - loss: 0.0738 - generator_loss: 0.0407 - generator_xpred_loss: 0.0153 - generator_yfake_loss: 0.9749 - generator_yreal_loss: 0.9859 - discriminator_loss: 0.0330 - discriminator_xpred_loss: 0.0153 - discriminator_yfake_loss: 0.5862 - discriminator_yreal_loss: 0.6055 - val_loss: 0.0739 - val_generator_loss: 0.0418 - val_generator_xpred_loss: 0.0151 - val_generator_yfake_loss: 1.0282 - val_generator_yreal_loss: 1.0630 - val_discriminator_loss: 0.0321 - val_discriminator_xpred_loss: 0.0151 - val_discriminator_yfake_loss: 0.5650 - val_discriminator_yreal_loss: 0.5537
# Epoch 62/100
#  - 20s - loss: 0.0736 - generator_loss: 0.0406 - generator_xpred_loss: 0.0153 - generator_yfake_loss: 0.9500 - generator_yreal_loss: 1.0028 - discriminator_loss: 0.0330 - discriminator_xpred_loss: 0.0153 - discriminator_yfake_loss: 0.5995 - discriminator_yreal_loss: 0.5939 - val_loss: 0.0730 - val_generator_loss: 0.0400 - val_generator_xpred_loss: 0.0149 - val_generator_yfake_loss: 1.0250 - val_generator_yreal_loss: 0.9087 - val_discriminator_loss: 0.0331 - val_discriminator_xpred_loss: 0.0149 - val_discriminator_yfake_loss: 0.5741 - val_discriminator_yreal_loss: 0.6672
# Epoch 63/100
#  - 19s - loss: 0.0740 - generator_loss: 0.0409 - generator_xpred_loss: 0.0153 - generator_yfake_loss: 0.9825 - generator_yreal_loss: 0.9989 - discriminator_loss: 0.0331 - discriminator_xpred_loss: 0.0153 - discriminator_yfake_loss: 0.5955 - discriminator_yreal_loss: 0.6031 - val_loss: 0.0736 - val_generator_loss: 0.0411 - val_generator_xpred_loss: 0.0153 - val_generator_yfake_loss: 0.9533 - val_generator_yreal_loss: 1.0458 - val_discriminator_loss: 0.0326 - val_discriminator_xpred_loss: 0.0153 - val_discriminator_yfake_loss: 0.5829 - val_discriminator_yreal_loss: 0.5667
# Epoch 64/100
#  - 20s - loss: 0.0736 - generator_loss: 0.0407 - generator_xpred_loss: 0.0152 - generator_yfake_loss: 0.9801 - generator_yreal_loss: 0.9951 - discriminator_loss: 0.0329 - discriminator_xpred_loss: 0.0152 - discriminator_yfake_loss: 0.5882 - discriminator_yreal_loss: 0.6044 - val_loss: 0.0734 - val_generator_loss: 0.0412 - val_generator_xpred_loss: 0.0151 - val_generator_yfake_loss: 1.0716 - val_generator_yreal_loss: 0.9743 - val_discriminator_loss: 0.0322 - val_discriminator_xpred_loss: 0.0151 - val_discriminator_yfake_loss: 0.5381 - val_discriminator_yreal_loss: 0.5983
# Epoch 70/100
#  - 21s - loss: 0.0732 - generator_loss: 0.0404 - generator_xpred_loss: 0.0150 - generator_yfake_loss: 0.9655 - generator_yreal_loss: 0.9938 - discriminator_loss: 0.0328 - discriminator_xpred_loss: 0.0150 - discriminator_yfake_loss: 0.5963 - discriminator_yreal_loss: 0.6011 - val_loss: 0.0726 - val_generator_loss: 0.0399 - val_generator_xpred_loss: 0.0147 - val_generator_yfake_loss: 0.9313 - val_generator_yreal_loss: 1.0137 - val_discriminator_loss: 0.0327 - val_discriminator_xpred_loss: 0.0147 - val_discriminator_yfake_loss: 0.6374 - val_discriminator_yreal_loss: 0.5860
# Epoch 71/100
#  - 22s - loss: 0.0733 - generator_loss: 0.0405 - generator_xpred_loss: 0.0151 - generator_yfake_loss: 0.9628 - generator_yreal_loss: 1.0112 - discriminator_loss: 0.0328 - discriminator_xpred_loss: 0.0151 - discriminator_yfake_loss: 0.6027 - discriminator_yreal_loss: 0.5964 - val_loss: 0.0725 - val_generator_loss: 0.0408 - val_generator_xpred_loss: 0.0145 - val_generator_yfake_loss: 1.0149 - val_generator_yreal_loss: 1.0486 - val_discriminator_loss: 0.0317 - val_discriminator_xpred_loss: 0.0145 - val_discriminator_yfake_loss: 0.5670 - val_discriminator_yreal_loss: 0.5844
# Epoch 72/100
#  - 22s - loss: 0.0732 - generator_loss: 0.0405 - generator_xpred_loss: 0.0150 - generator_yfake_loss: 0.9862 - generator_yreal_loss: 0.9962 - discriminator_loss: 0.0327 - discriminator_xpred_loss: 0.0150 - discriminator_yfake_loss: 0.5940 - discriminator_yreal_loss: 0.6106 - val_loss: 0.0731 - val_generator_loss: 0.0398 - val_generator_xpred_loss: 0.0152 - val_generator_yfake_loss: 0.8496 - val_generator_yreal_loss: 1.0334 - val_discriminator_loss: 0.0333 - val_discriminator_xpred_loss: 0.0152 - val_discriminator_yfake_loss: 0.6727 - val_discriminator_yreal_loss: 0.5634
# Epoch 73/100
#  - 22s - loss: 0.0724 - generator_loss: 0.0400 - generator_xpred_loss: 0.0148 - generator_yfake_loss: 0.9566 - generator_yreal_loss: 0.9930 - discriminator_loss: 0.0324 - discriminator_xpred_loss: 0.0148 - discriminator_yfake_loss: 0.5928 - discriminator_yreal_loss: 0.5970 - val_loss: 0.0712 - val_generator_loss: 0.0391 - val_generator_xpred_loss: 0.0144 - val_generator_yfake_loss: 1.0248 - val_generator_yreal_loss: 0.8801 - val_discriminator_loss: 0.0321 - val_discriminator_xpred_loss: 0.0144 - val_discriminator_yfake_loss: 0.5557 - val_discriminator_yreal_loss: 0.6503
# Epoch 74/100
#  - 21s - loss: 0.0722 - generator_loss: 0.0398 - generator_xpred_loss: 0.0148 - generator_yfake_loss: 0.9566 - generator_yreal_loss: 0.9801 - discriminator_loss: 0.0324 - discriminator_xpred_loss: 0.0148 - discriminator_yfake_loss: 0.5951 - discriminator_yreal_loss: 0.5973 - val_loss: 0.0721 - val_generator_loss: 0.0403 - val_generator_xpred_loss: 0.0147 - val_generator_yfake_loss: 0.9486 - val_generator_yreal_loss: 1.0454 - val_discriminator_loss: 0.0318 - val_discriminator_xpred_loss: 0.0147 - val_discriminator_yfake_loss: 0.5779 - val_discriminator_yreal_loss: 0.5591
# Epoch 75/100
#  - 22s - loss: 0.0717 - generator_loss: 0.0397 - generator_xpred_loss: 0.0145 - generator_yfake_loss: 0.9710 - generator_yreal_loss: 0.9786 - discriminator_loss: 0.0320 - discriminator_xpred_loss: 0.0145 - discriminator_yfake_loss: 0.5810 - discriminator_yreal_loss: 0.5985 - val_loss: 0.0712 - val_generator_loss: 0.0396 - val_generator_xpred_loss: 0.0143 - val_generator_yfake_loss: 1.0164 - val_generator_yreal_loss: 0.9542 - val_discriminator_loss: 0.0316 - val_discriminator_xpred_loss: 0.0143 - val_discriminator_yfake_loss: 0.5642 - val_discriminator_yreal_loss: 0.6001
# Epoch 76/100
#  - 23s - loss: 0.0720 - generator_loss: 0.0398 - generator_xpred_loss: 0.0147 - generator_yfake_loss: 0.9538 - generator_yreal_loss: 0.9965 - discriminator_loss: 0.0322 - discriminator_xpred_loss: 0.0147 - discriminator_yfake_loss: 0.5966 - discriminator_yreal_loss: 0.5884 - val_loss: 0.0720 - val_generator_loss: 0.0401 - val_generator_xpred_loss: 0.0145 - val_generator_yfake_loss: 0.9657 - val_generator_yreal_loss: 1.0303 - val_discriminator_loss: 0.0320 - val_discriminator_xpred_loss: 0.0145 - val_discriminator_yfake_loss: 0.5896 - val_discriminator_yreal_loss: 0.5950
# Epoch 77/100
#  - 22s - loss: 0.0722 - generator_loss: 0.0400 - generator_xpred_loss: 0.0146 - generator_yfake_loss: 0.9837 - generator_yreal_loss: 0.9860 - discriminator_loss: 0.0322 - discriminator_xpred_loss: 0.0146 - discriminator_yfake_loss: 0.5872 - discriminator_yreal_loss: 0.6026 - val_loss: 0.0717 - val_generator_loss: 0.0393 - val_generator_xpred_loss: 0.0147 - val_generator_yfake_loss: 0.8792 - val_generator_yreal_loss: 1.0173 - val_discriminator_loss: 0.0324 - val_discriminator_xpred_loss: 0.0147 - val_discriminator_yfake_loss: 0.6425 - val_discriminator_yreal_loss: 0.5578
# Epoch 78/100
#  - 23s - loss: 0.0717 - generator_loss: 0.0395 - generator_xpred_loss: 0.0146 - generator_yfake_loss: 0.9497 - generator_yreal_loss: 0.9824 - discriminator_loss: 0.0321 - discriminator_xpred_loss: 0.0146 - discriminator_yfake_loss: 0.5934 - discriminator_yreal_loss: 0.5958 - val_loss: 0.0713 - val_generator_loss: 0.0395 - val_generator_xpred_loss: 0.0142 - val_generator_yfake_loss: 1.0626 - val_generator_yreal_loss: 0.9070 - val_discriminator_loss: 0.0318 - val_discriminator_xpred_loss: 0.0142 - val_discriminator_yfake_loss: 0.5414 - val_discriminator_yreal_loss: 0.6545
# Epoch 79/100
#  - 22s - loss: 0.0720 - generator_loss: 0.0397 - generator_xpred_loss: 0.0147 - generator_yfake_loss: 0.9596 - generator_yreal_loss: 0.9834 - discriminator_loss: 0.0323 - discriminator_xpred_loss: 0.0147 - discriminator_yfake_loss: 0.6003 - discriminator_yreal_loss: 0.5992 - val_loss: 0.0721 - val_generator_loss: 0.0399 - val_generator_xpred_loss: 0.0149 - val_generator_yfake_loss: 0.9254 - val_generator_yreal_loss: 1.0113 - val_discriminator_loss: 0.0323 - val_discriminator_xpred_loss: 0.0149 - val_discriminator_yfake_loss: 0.5956 - val_discriminator_yreal_loss: 0.5812
# Epoch 80/100
#  - 22s - loss: 0.0726 - generator_loss: 0.0402 - generator_xpred_loss: 0.0147 - generator_yfake_loss: 0.9865 - generator_yreal_loss: 0.9980 - discriminator_loss: 0.0324 - discriminator_xpred_loss: 0.0147 - discriminator_yfake_loss: 0.5911 - discriminator_yreal_loss: 0.6103 - val_loss: 0.0723 - val_generator_loss: 0.0406 - val_generator_xpred_loss: 0.0147 - val_generator_yfake_loss: 1.0890 - val_generator_yreal_loss: 0.9379 - val_discriminator_loss: 0.0318 - val_discriminator_xpred_loss: 0.0147 - val_discriminator_yfake_loss: 0.5340 - val_discriminator_yreal_loss: 0.6165
# Epoch 81/100
#  - 22s - loss: 0.0719 - generator_loss: 0.0397 - generator_xpred_loss: 0.0146 - generator_yfake_loss: 0.9449 - generator_yreal_loss: 0.9922 - discriminator_loss: 0.0323 - discriminator_xpred_loss: 0.0146 - discriminator_yfake_loss: 0.6039 - discriminator_yreal_loss: 0.5965 - val_loss: 0.0713 - val_generator_loss: 0.0396 - val_generator_xpred_loss: 0.0143 - val_generator_yfake_loss: 0.9589 - val_generator_yreal_loss: 1.0024 - val_discriminator_loss: 0.0317 - val_discriminator_xpred_loss: 0.0143 - val_discriminator_yfake_loss: 0.5848 - val_discriminator_yreal_loss: 0.5928
# Epoch 82/100
#  - 22s - loss: 0.0714 - generator_loss: 0.0394 - generator_xpred_loss: 0.0144 - generator_yfake_loss: 0.9678 - generator_yreal_loss: 0.9723 - discriminator_loss: 0.0319 - discriminator_xpred_loss: 0.0144 - discriminator_yfake_loss: 0.5850 - discriminator_yreal_loss: 0.6051 - val_loss: 0.0722 - val_generator_loss: 0.0399 - val_generator_xpred_loss: 0.0147 - val_generator_yfake_loss: 0.9373 - val_generator_yreal_loss: 1.0243 - val_discriminator_loss: 0.0324 - val_discriminator_xpred_loss: 0.0147 - val_discriminator_yfake_loss: 0.6249 - val_discriminator_yreal_loss: 0.5827
# Epoch 83/100
#  - 22s - loss: 0.0719 - generator_loss: 0.0396 - generator_xpred_loss: 0.0146 - generator_yfake_loss: 0.9496 - generator_yreal_loss: 0.9925 - discriminator_loss: 0.0322 - discriminator_xpred_loss: 0.0146 - discriminator_yfake_loss: 0.6044 - discriminator_yreal_loss: 0.5997 - val_loss: 0.0711 - val_generator_loss: 0.0392 - val_generator_xpred_loss: 0.0141 - val_generator_yfake_loss: 1.0243 - val_generator_yreal_loss: 0.9260 - val_discriminator_loss: 0.0319 - val_discriminator_xpred_loss: 0.0141 - val_discriminator_yfake_loss: 0.5686 - val_discriminator_yreal_loss: 0.6528
# Epoch 84/100
#  - 22s - loss: 0.0708 - generator_loss: 0.0390 - generator_xpred_loss: 0.0143 - generator_yfake_loss: 0.9503 - generator_yreal_loss: 0.9612 - discriminator_loss: 0.0318 - discriminator_xpred_loss: 0.0143 - discriminator_yfake_loss: 0.5901 - discriminator_yreal_loss: 0.5991 - val_loss: 0.0707 - val_generator_loss: 0.0386 - val_generator_xpred_loss: 0.0145 - val_generator_yfake_loss: 0.8670 - val_generator_yreal_loss: 0.9861 - val_discriminator_loss: 0.0321 - val_discriminator_xpred_loss: 0.0145 - val_discriminator_yfake_loss: 0.6336 - val_discriminator_yreal_loss: 0.5709
# Epoch 85/100
#  - 21s - loss: 0.0713 - generator_loss: 0.0394 - generator_xpred_loss: 0.0144 - generator_yfake_loss: 0.9603 - generator_yreal_loss: 0.9856 - discriminator_loss: 0.0318 - discriminator_xpred_loss: 0.0144 - discriminator_yfake_loss: 0.5902 - discriminator_yreal_loss: 0.6000 - val_loss: 0.0702 - val_generator_loss: 0.0388 - val_generator_xpred_loss: 0.0140 - val_generator_yfake_loss: 1.0235 - val_generator_yreal_loss: 0.9048 - val_discriminator_loss: 0.0314 - val_discriminator_xpred_loss: 0.0140 - val_discriminator_yfake_loss: 0.5522 - val_discriminator_yreal_loss: 0.6271
# Epoch 86/100
#  - 21s - loss: 0.0714 - generator_loss: 0.0394 - generator_xpred_loss: 0.0144 - generator_yfake_loss: 0.9524 - generator_yreal_loss: 0.9839 - discriminator_loss: 0.0320 - discriminator_xpred_loss: 0.0144 - discriminator_yfake_loss: 0.6013 - discriminator_yreal_loss: 0.5981 - val_loss: 0.0713 - val_generator_loss: 0.0395 - val_generator_xpred_loss: 0.0146 - val_generator_yfake_loss: 0.9383 - val_generator_yreal_loss: 0.9916 - val_discriminator_loss: 0.0318 - val_discriminator_xpred_loss: 0.0146 - val_discriminator_yfake_loss: 0.5749 - val_discriminator_yreal_loss: 0.5924
# Epoch 87/100
#  - 24s - loss: 0.0714 - generator_loss: 0.0394 - generator_xpred_loss: 0.0144 - generator_yfake_loss: 0.9658 - generator_yreal_loss: 0.9729 - discriminator_loss: 0.0320 - discriminator_xpred_loss: 0.0144 - discriminator_yfake_loss: 0.5899 - discriminator_yreal_loss: 0.6059 - val_loss: 0.0707 - val_generator_loss: 0.0390 - val_generator_xpred_loss: 0.0142 - val_generator_yfake_loss: 0.9397 - val_generator_yreal_loss: 0.9829 - val_discriminator_loss: 0.0317 - val_discriminator_xpred_loss: 0.0142 - val_discriminator_yfake_loss: 0.6057 - val_discriminator_yreal_loss: 0.5831
# Epoch 88/100
#  - 21s - loss: 0.0706 - generator_loss: 0.0388 - generator_xpred_loss: 0.0142 - generator_yfake_loss: 0.9304 - generator_yreal_loss: 0.9713 - discriminator_loss: 0.0317 - discriminator_xpred_loss: 0.0142 - discriminator_yfake_loss: 0.5980 - discriminator_yreal_loss: 0.5941 - val_loss: 0.0710 - val_generator_loss: 0.0395 - val_generator_xpred_loss: 0.0140 - val_generator_yfake_loss: 1.0184 - val_generator_yreal_loss: 0.9784 - val_discriminator_loss: 0.0314 - val_discriminator_xpred_loss: 0.0140 - val_discriminator_yfake_loss: 0.5632 - val_discriminator_yreal_loss: 0.6253
# Epoch 89/100
#  - 21s - loss: 0.0713 - generator_loss: 0.0393 - generator_xpred_loss: 0.0144 - generator_yfake_loss: 0.9639 - generator_yreal_loss: 0.9676 - discriminator_loss: 0.0320 - discriminator_xpred_loss: 0.0144 - discriminator_yfake_loss: 0.5978 - discriminator_yreal_loss: 0.6100 - val_loss: 0.0713 - val_generator_loss: 0.0389 - val_generator_xpred_loss: 0.0145 - val_generator_yfake_loss: 0.8599 - val_generator_yreal_loss: 1.0162 - val_discriminator_loss: 0.0324 - val_discriminator_xpred_loss: 0.0145 - val_discriminator_yfake_loss: 0.6592 - val_discriminator_yreal_loss: 0.5683
# Epoch 90/100
#  - 21s - loss: 0.0706 - generator_loss: 0.0389 - generator_xpred_loss: 0.0142 - generator_yfake_loss: 0.9414 - generator_yreal_loss: 0.9664 - discriminator_loss: 0.0317 - discriminator_xpred_loss: 0.0142 - discriminator_yfake_loss: 0.5944 - discriminator_yreal_loss: 0.5997 - val_loss: 0.0703 - val_generator_loss: 0.0389 - val_generator_xpred_loss: 0.0139 - val_generator_yfake_loss: 1.0477 - val_generator_yreal_loss: 0.9000 - val_discriminator_loss: 0.0313 - val_discriminator_xpred_loss: 0.0139 - val_discriminator_yfake_loss: 0.5468 - val_discriminator_yreal_loss: 0.6409
# Epoch 91/100
#  - 22s - loss: 0.0708 - generator_loss: 0.0389 - generator_xpred_loss: 0.0143 - generator_yfake_loss: 0.9424 - generator_yreal_loss: 0.9680 - discriminator_loss: 0.0318 - discriminator_xpred_loss: 0.0143 - discriminator_yfake_loss: 0.5999 - discriminator_yreal_loss: 0.6009 - val_loss: 0.0706 - val_generator_loss: 0.0395 - val_generator_xpred_loss: 0.0141 - val_generator_yfake_loss: 0.9718 - val_generator_yreal_loss: 1.0064 - val_discriminator_loss: 0.0311 - val_discriminator_xpred_loss: 0.0141 - val_discriminator_yfake_loss: 0.5641 - val_discriminator_yreal_loss: 0.5792
# Epoch 92/100
#  - 21s - loss: 0.0706 - generator_loss: 0.0389 - generator_xpred_loss: 0.0142 - generator_yfake_loss: 0.9550 - generator_yreal_loss: 0.9651 - discriminator_loss: 0.0317 - discriminator_xpred_loss: 0.0142 - discriminator_yfake_loss: 0.5928 - discriminator_yreal_loss: 0.6043 - val_loss: 0.0708 - val_generator_loss: 0.0381 - val_generator_xpred_loss: 0.0144 - val_generator_yfake_loss: 0.8940 - val_generator_yreal_loss: 0.9197 - val_discriminator_loss: 0.0327 - val_discriminator_xpred_loss: 0.0144 - val_discriminator_yfake_loss: 0.6424 - val_discriminator_yreal_loss: 0.6349
# Epoch 93/100
#  - 21s - loss: 0.0712 - generator_loss: 0.0392 - generator_xpred_loss: 0.0144 - generator_yfake_loss: 0.9433 - generator_yreal_loss: 0.9861 - discriminator_loss: 0.0320 - discriminator_xpred_loss: 0.0144 - discriminator_yfake_loss: 0.6061 - discriminator_yreal_loss: 0.6033 - val_loss: 0.0703 - val_generator_loss: 0.0386 - val_generator_xpred_loss: 0.0140 - val_generator_yfake_loss: 1.0184 - val_generator_yreal_loss: 0.8825 - val_discriminator_loss: 0.0318 - val_discriminator_xpred_loss: 0.0140 - val_discriminator_yfake_loss: 0.5544 - val_discriminator_yreal_loss: 0.6672
# Epoch 94/100
#  - 22s - loss: 0.0712 - generator_loss: 0.0393 - generator_xpred_loss: 0.0143 - generator_yfake_loss: 0.9691 - generator_yreal_loss: 0.9738 - discriminator_loss: 0.0319 - discriminator_xpred_loss: 0.0143 - discriminator_yfake_loss: 0.5985 - discriminator_yreal_loss: 0.6084 - val_loss: 0.0713 - val_generator_loss: 0.0391 - val_generator_xpred_loss: 0.0144 - val_generator_yfake_loss: 0.8800 - val_generator_yreal_loss: 1.0309 - val_discriminator_loss: 0.0323 - val_discriminator_xpred_loss: 0.0144 - val_discriminator_yfake_loss: 0.6555 - val_discriminator_yreal_loss: 0.5746
# Epoch 95/100
#  - 21s - loss: 0.0704 - generator_loss: 0.0388 - generator_xpred_loss: 0.0141 - generator_yfake_loss: 0.9463 - generator_yreal_loss: 0.9681 - discriminator_loss: 0.0316 - discriminator_xpred_loss: 0.0141 - discriminator_yfake_loss: 0.5944 - discriminator_yreal_loss: 0.6024 - val_loss: 0.0695 - val_generator_loss: 0.0380 - val_generator_xpred_loss: 0.0139 - val_generator_yfake_loss: 0.9556 - val_generator_yreal_loss: 0.8978 - val_discriminator_loss: 0.0315 - val_discriminator_xpred_loss: 0.0139 - val_discriminator_yfake_loss: 0.5767 - val_discriminator_yreal_loss: 0.6237
# Epoch 96/100
#  - 23s - loss: 0.0701 - generator_loss: 0.0385 - generator_xpred_loss: 0.0141 - generator_yfake_loss: 0.9317 - generator_yreal_loss: 0.9600 - discriminator_loss: 0.0316 - discriminator_xpred_loss: 0.0141 - discriminator_yfake_loss: 0.5976 - discriminator_yreal_loss: 0.5973 - val_loss: 0.0701 - val_generator_loss: 0.0388 - val_generator_xpred_loss: 0.0140 - val_generator_yfake_loss: 0.9741 - val_generator_yreal_loss: 0.9503 - val_discriminator_loss: 0.0313 - val_discriminator_xpred_loss: 0.0140 - val_discriminator_yfake_loss: 0.5595 - val_discriminator_yreal_loss: 0.6090
# Epoch 97/100
#  - 21s - loss: 0.0701 - generator_loss: 0.0386 - generator_xpred_loss: 0.0140 - generator_yfake_loss: 0.9496 - generator_yreal_loss: 0.9563 - discriminator_loss: 0.0315 - discriminator_xpred_loss: 0.0140 - discriminator_yfake_loss: 0.5899 - discriminator_yreal_loss: 0.6034 - val_loss: 0.0705 - val_generator_loss: 0.0389 - val_generator_xpred_loss: 0.0141 - val_generator_yfake_loss: 0.9229 - val_generator_yreal_loss: 1.0016 - val_discriminator_loss: 0.0316 - val_discriminator_xpred_loss: 0.0141 - val_discriminator_yfake_loss: 0.6217 - val_discriminator_yreal_loss: 0.5711
# Epoch 98/100
#  - 21s - loss: 0.0707 - generator_loss: 0.0389 - generator_xpred_loss: 0.0141 - generator_yfake_loss: 0.9426 - generator_yreal_loss: 0.9811 - discriminator_loss: 0.0317 - discriminator_xpred_loss: 0.0141 - discriminator_yfake_loss: 0.6034 - discriminator_yreal_loss: 0.5998 - val_loss: 0.0705 - val_generator_loss: 0.0389 - val_generator_xpred_loss: 0.0138 - val_generator_yfake_loss: 0.9948 - val_generator_yreal_loss: 0.9577 - val_discriminator_loss: 0.0315 - val_discriminator_xpred_loss: 0.0138 - val_discriminator_yfake_loss: 0.5855 - val_discriminator_yreal_loss: 0.6267
# Epoch 99/100
#  - 21s - loss: 0.0703 - generator_loss: 0.0387 - generator_xpred_loss: 0.0140 - generator_yfake_loss: 0.9512 - generator_yreal_loss: 0.9592 - discriminator_loss: 0.0316 - discriminator_xpred_loss: 0.0140 - discriminator_yfake_loss: 0.5984 - discriminator_yreal_loss: 0.6066 - val_loss: 0.0702 - val_generator_loss: 0.0385 - val_generator_xpred_loss: 0.0142 - val_generator_yfake_loss: 0.9101 - val_generator_yreal_loss: 0.9683 - val_discriminator_loss: 0.0317 - val_discriminator_xpred_loss: 0.0142 - val_discriminator_yfake_loss: 0.6080 - val_discriminator_yreal_loss: 0.5860
# Epoch 100/100
#  - 22s - loss: 0.0704 - generator_loss: 0.0388 - generator_xpred_loss: 0.0140 - generator_yfake_loss: 0.9484 - generator_yreal_loss: 0.9739 - discriminator_loss: 0.0316 - discriminator_xpred_loss: 0.0140 - discriminator_yfake_loss: 0.5969 - discriminator_yreal_loss: 0.6046 - val_loss: 0.0703 - val_generator_loss: 0.0389 - val_generator_xpred_loss: 0.0139 - val_generator_yfake_loss: 1.0514 - val_generator_yreal_loss: 0.8941 - val_discriminator_loss: 0.0314 - val_discriminator_xpred_loss: 0.0139 - val_discriminator_yfake_loss: 0.5445 - val_discriminator_yreal_loss: 0.6565

# %%
# Build model
from keras.layers import Dense, Dropout, Flatten, Input, MaxPooling1D, Convolution1D, Embedding

filter_sizes = (3, 8)
num_filters = 10
hidden_dims = 200

input_shape = (max_len,)

model_input = Input(shape=input_shape)

z = embedding_layer(model_input)



# Convolutional block
conv_blocks = []
for sz in filter_sizes:
    conv = Convolution1D(filters=num_filters,
                         kernel_size=sz,
                         padding="valid",
                         activation="relu",
                         strides=1)(z)
    conv = MaxPooling1D(pool_size=2)(conv)
    conv = Flatten()(conv)
    conv_blocks.append(conv)
z = Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]

# z = Dense(hidden_dims, activation="relu")(z)
# model_output = Dense(1, activation="sigmoid")(z)
model_output = z

model = Model(model_input, model_output)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model.predict(np.random.randint(20, size=(10,15))).shape
# Out:
# (10, 100)
