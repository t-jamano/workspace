# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from Utils import *
from Models import *

# %%
run1 = read_outputs2("/work/data/out/dssm_gru2_30M_QD_ml15_2018_08_08_17:40:48_h200_l100_k2_n1_ml15_w50512_b64_e5_a1.0_<keras.optimizers.Adam object at 0x7f1020c009e8>_50K_BPE")
run2 = read_outputs2("/work/data/out/dssm_avg_30M_QD_ml15_2018_08_08_20:48:01_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fa6fbda5ac8>_50K_BPE")
run3 = read_outputs2("/work/data/out/seq2seq_ori2_30M_QD_ml15_2018_08_07_19:39:50_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fa8ff898dd8>_50K_BPE")
run4 = read_outputs2("/work/data/out/dssm_max_30M_QQ_ml15_2018_08_08_20:59:58_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fcf87067ac8>_50K_BPE")


# bow_pr_wae
# run4 = read_outputs2("/work/data/out/bow_pr_aae_30M_QQ_ml15_2018_08_08_23:31:23_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7f53530adb00>_50K_BPE")
run5 = read_outputs2("/work/data/out/bow_pr_wae_30M_QQ_ml15_2018_08_08_23:00:35_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fd6dacfaac8>_50K_BPE")
run6 = read_outputs2("/work/data/out/bow_pr_aae_30M_QQ_ml15_2018_08_08_23:31:23_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7f53530adb00>_50K_BPE")

# Q > AAE > D
run7 = read_outputs2("/work/data/out/aae_30M_QD_ml15_2018_08_14_00:55:04_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7faa7b432128>_50K_BPE")

visualise([run1, run2, run3, run4, run5, run6, run7])
visualise([run3, run4, run5, run6, run7])

# %%
run101 = read_outputs2("/work/data/out/pr_aae_m2_30M_QD_ml15_2018_08_14_22:08:38_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7f915afdd978>_50K_BPE")
run102 = read_outputs2("/work/data/out/pr_wae_m2_30M_QD_ml15_2018_08_15_02:20:07_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fb9fd8fab00>_50K_BPE")
run103 = read_outputs2("/work/data/out/aae_pair_30M_QD_ml15_2018_08_15_01:49:34_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7ff596da8a58>_50K_BPE")
run104 = read_outputs2("/work/data/out/wae_pair_30M_QD_ml15_2018_08_15_02:14:56_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fa905d4ea20>_50K_BPE")
run105 = read_outputs2("/work/data/out/bow_pr_avg_aae_m2_30M_QQ_ml15_2018_08_13_15:56:35_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fb6e25149e8>_50K_BPE")
# run304 = read_outputs2("/work/data/out/pr_aae_m2_30M_QQ_ml15_2018_08_10_00:45:00_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7f09bfc4d3c8>_50K_BPE")
# 106-107 used MaxPooling
run106 = read_outputs2("/work/data/out/bow_pr_wae_30M_QQ_ml15_2018_08_08_23:00:35_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7fd6dacfaac8>_50K_BPE")
run107 = read_outputs2("/work/data/out/bow_pr_aae_30M_QQ_ml15_2018_08_08_23:31:23_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7f53530adb00>_50K_BPE")
run108 = read_outputs2("/work/data/out/dssm_avg_30M_QQ_ml15_2018_08_08_20:56:54_h200_l100_k2_n1_ml15_w50512_b64_e1_a1.0_<keras.optimizers.Adam object at 0x7f1a7a38e978>_50K_BPE")


visualise([run101, run102, run103, run104, run1])
visualise([run105, run108,run2])
visualise([run105, run108])
visualise([run101, run103, run1])


visualise([run101], focus=["generator_loss", "discriminator_loss"])

# %%
visualise([run1, run2])

# %%
for i in [run101, run102, run103, run104, run1]:
    meanResults(i)
# Out:
# pr_aae_m2 0.5100501773049646 0.843009219858156 0.5354351063829786 0.748820744680851 0.9224980496453901 0.5405803191489361
# pr_wae_m2 0.48158582677165357 0.8100809055118112 0.5008061023622047 0.6457114173228348 0.7562206692913386 0.024314173228346454
# aae_pair 0.5094859582542695 0.8422776091081594 0.5412280834914611 0.7479313092979127 0.9214254269449715 0.5387660341555978
# wae_pair 0.4799636363636363 0.799689037433155 0.43435053475935825 0.5782058823529412 0.724763101604278 nan
# dssm_gru2 0.5160344387755101 0.8447272959183674 0.501983843537415 0.7649275510204082 0.9310948979591839 0.6137936224489795

# %%
# feay
def read_outputs2(file_dir, isOld=False):
    results = {}
    
    may, june, july, loss, q_rec_loss, d_rec_loss, qd_loss, qd_rec_loss, dq_rec_loss, gan_loss, acc, v_loss = [], [], [], [], [], [], [], [], [], [], [], []
    model_name = ""
    with open (file_dir, "r") as myfile:
        
        for line in myfile:
            s = line.split(",")
            if model_name == "":
                model_name = s[0]
            if len(s) == 3:
                break
            
            start_at = 3 if isOld else 4
            
            for i in range(start_at, len(s), 1):
                val_name = s[i].split("=")[0].replace(" ", "")
                val = s[i].split("=")[-1]
                
                if val_name in results:
                    results[val_name].append(float(val))
                else:
                    results[val_name] = []
                    results[val_name].append(float(val))
    
    if "Loss" in results.keys():
        results["loss"] = results.pop("Loss")
        results["val_loss"] = results.pop("V_Loss")
    
    
    
    return model_name, results, list(results.keys())
    
            
#     return model_name, may, june, july, loss, v_loss, q_rec_loss, d_rec_loss, qd_loss, qd_rec_loss, dq_rec_loss, gan_loss, acc

def meanResults(run):
    print(run[0], np.mean(run[1]['May']), np.mean(run[1]['June']), np.mean(run[1]['July']), np.mean(run[1]['Quora']), np.mean(run[1]['Para']), np.mean(run[1]['STS']) )
def maxResults(run):
    print(run[0], np.max(run[1]['May']), np.max(run[1]['June']), np.max(run[1]['July']), np.max(run[1]['Quora']), np.max(run[1]['Para']), np.max(run[1]['STS']))

def visualise(results, focus=["May", "June", "July", "Quora", "Para", "STS"], legends=None, save=None, earlyStop=None):
    
    width = 18
    height = 2
    
    plt.figure(figsize=(width, height))
    
    plt_num = len(focus)
    
    for i in range(plt_num):
        plt.subplot(1, plt_num, i+1)
        
        for r in results:
            if earlyStop != None:
                plt.plot([(i+1) for i in range(earlyStop)], r[1][focus[i]][:earlyStop])
            else:
                plt.plot([(i+1) for i in range(len(r[1][focus[i]]))], r[1][focus[i]])
                
        plt.title(focus[i])
        plt.xlabel('Iterations')
        
        

    if legends == None:
        plt.legend([i[0] for i in results],bbox_to_anchor=(1.04,1), loc="upper left")
    else:
        plt.legend([i for i in legends],bbox_to_anchor=(1.04,1), loc="upper left")


    plt.subplots_adjust(wspace=0.3)
    if save != None:
        plt.savefig('/work/png/%s' %save, bbox_inches='tight',pad_inches=1, dpi=300)
    plt.show()

# compare train of val of the model
def visualise_train_val(run, focus1, focus2):
    
    res1, res2 = {}, {}
    for i, j in zip(focus1, focus2):
        res1[i] = run[1][i]    
        res2[i] = run[1][j]
    
    r1 = run[0], res1
    r2 = run[0], res2
    
    visualise([r1, r2], focus=focus1, legends=["Train", "Val"])

# %%
def name(self):
    if self.enableCond:
        return "cvae"
    elif not self.enableGRU:
        return "vae%d_max" % self.mode
    elif self.enableGRU and not self.enableBi:
        return "vae%d" % self.mode if not self.enableKL else "vae_kl"
    return "vae%d_bi" % self.mode
